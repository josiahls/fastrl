# %%
#hide
#skip
# %config Completer.use_jedi = False
# upgrade fastrl on colab
! [ -e /content ] && pip install -Uqq fastrl['dev'] pyvirtualdisplay && \
                     apt-get install -y xvfb python-opengl > /dev/null 2>&1 
# NOTE: IF YOU SEE VERSION ERRORS, IT IS SAFE TO IGNORE THEM. COLAB IS BEHIND IN SOME OF THE PACKAGE VERSIONS

# %%
# hide
from fastcore.imports import in_colab
# Since colab still requires tornado<6, we don't want to import nbdev if we don't have to
if not in_colab():
    from nbverbose.showdoc import *
    from nbdev.imports import *
    if not os.environ.get("IN_TEST", None):
#         assert IN_NOTEBOOK
        assert not IN_COLAB
        assert IN_IPYTHON
else:
    # Virtual display is needed for colab
    from pyvirtualdisplay import Display
    display = Display(visible=0, size=(400, 300))
    display.start()

# %%
# default_exp data.gym

# %%
# export
# Python native modules
import os
from collections import deque
from copy import deepcopy
from time import sleep
from typing import *
from warnings import warn
# Third party libs
from fastcore.all import *
from fastai.torch_basics import *
from fastai.data.all import *
from fastai.basics import *
from fastai.callback.all import *
from torch.utils.data import Dataset
from torch import nn
import torch
import gym
try:
    import pybulletgym
except ModuleNotFoundError as e:pass
import numpy as np
from torch.utils.tensorboard import SummaryWriter
# Local modules
from fastrl.core import *
from fastrl.callback.core import *
from fastrl.data.block import *
from fastrl.agent import *

# %% [markdown]
# # Data Block Gym
# > openai gym sources

# %% [markdown]
# ## GymSource
# > The base iterable used for iterating through environments.

# %%
# export
class ReturnHistory(Transform):
    def encodes(self,o:dict):
        source,data=o['source'],o['history']
        history=sum(source.histories)
        if len(source.histories)==1 and sum(history['done'])>0:
            source.all_done=TensorBatch([[True]])
            history['all_done']=TensorBatch([[True]])
        source.histories.popleft()
        return {'source':source,'history':history}

# %%
import logging

# %%
_logger=logging.getLogger()
logging.basicConfig(format='[%(asctime)s.%(msecs)03d] p%(process)s {%(filename)s:%(lineno)d} %(levelname)s - %(message)s',
                datefmt='%m-%d %H:%M:%S',level='INFO')

# %%
# export
class TstCallback(AgentCallback):
    def __init__(self,action_space=None,constant=None): 
        store_attr()
        self.action_executions=0
        
    def before_noise(self):
        bs=self.experience['state'].shape[0]
        self.agent.action=Tensor([[self.constant] if self.constant is not None else 
                                   self.action_space.sample() 
                                   for _ in range(bs)])
        self.agent.experience=D(merge(self.experience,{'random_action':np.random.randint(0,3,(bs,1))}))
        
        self.action_executions+=1

def np_type_cast(a,dtype): return a.astype(dtype)
        
class GymLoop(LoopCallback):
    _methods=source_events
    _default='source'
    def __init__(self,env_name:str,agent=None,mode=None,
                 steps_count:int=1,steps_delta:int=1,seed:int=None,
                 worker_id:int=0,dtype=None): 
        store_attr()
        
    def initialize(self):
        self.source.histories=deque(maxlen=self.steps_count)    
        self.source.return_fn=Pipeline([ReturnHistory])
        if self.mode!='rgb_array': self.source.ignore_fields.append('image')
        self.source.worker_id=get_worker_info()
        self.source.worker_id=TensorBatch(np.array([[getattr(self.worker_id,'id',0)]]))
        
        self.source.env=gym.make(self.env_name)
        if isinstance(self.env.action_space,gym.spaces.Discrete): 
            self.dtype=int
        elif isinstance(self.env.action_space,gym.spaces.Box):    
            if issubclass(self.env.action_space.dtype.type,(float,np.floating)): 
                self.dtype=partial(np_type_cast,dtype=float)
            if issubclass(self.env.action_space.dtype.type,(int,np.integer)): 
                self.dtype=partial(np_type_cast,dtype=int)
        else:
            self.dtype=float
        
        self.agent=ifnone(self.agent,Agent(cbs=TstCallback(action_space=self.env.action_space)))
        self.source.episode_id=TensorBatch(np.array([[0]]))
        self.source.done=TensorBatch(np.array([[True]]))
        self.source.all_done=TensorBatch(np.array([[True]]))
    
    def reset(self):
        if len(self.histories)==0 and sum(self.all_done)>=1:
            self.source.env_id=TensorBatch(np.array([[0]]))
            self.source.reward=TensorBatch(np.array([[0.0]]))
            self.source.episode_id+=1
            self.source.accum_rewards=TensorBatch(np.array([[0.0]]))
            self.source.step=TensorBatch(np.array([[0]]))
            self.source.env_id=TensorBatch(np.array([[0]]))
            self.source.done=TensorBatch(np.array([[False]]))
            self.source.all_done=TensorBatch(np.array([[False]]))
            self.source.env.seed(self.seed)
            self.source.state=TensorBatch(self.env.reset()).unsqueeze(0)
            if self.mode=='rgb_array': 
                self.source.image=TensorBatch(np.expand_dims(self.env.render(self.mode).copy(),0))

    def before_episodes(self): self('initialize')
        
    def do_step(self):
        action,experience=self.agent.do_action(**self.data())
        for k,v in experience.items(): 
            if v is not None: setattr(self.source,k,TensorBatch(v))
        self.source.action=TensorBatch(action)
        step_action=self.action.numpy()[0]
        next_state,reward,done,_=self.env.step(self.dtype(step_action))
        self.source.next_state=TensorBatch(next_state).unsqueeze(0)
        self.source.reward=TensorBatch(np.expand_dims(reward,(0,1)))
        self.source.accum_rewards+=reward
        self.source.done=TensorBatch(np.expand_dims(done,(0,1)))
        if self.mode=='rgb_array': 
            self.source.image=TensorBatch(np.expand_dims(self.env.render(self.mode).copy(),0))
        self.source.step+=1
    
    def before_history(self):
        self.source.skip_history_return=False
        self.histories.append(deepcopy(self.data()))

        if self.done.sum().item()<1:
            self.source.skip_history_return=len(self.histories)<self.steps_count or \
                                            int(self.step.item())%self.steps_delta!=0
    
    def history(self):
        if sum(self.done)>0 and len(self.histories)>1 and self.steps_count>1: 
            self.source.loop_history_yield=True
            
    def after_history(self):
        self.source.state=self.source.next_state
            
            
add_docs(GymLoop,"Handles iterating through single openai gym (and varients).",
         before_history="""Primarily appends `self.data()` to `self.histories` however it also...
         
         If the number of elements in `self.histories` is empty, or about to be empty, and
         `self.done==True` it sets the `self.all_done` field.
         
         If `self.done==True` also determine if we should skip returning a history.
         Mainly if we need to accumulate the histories first.
         """,
         initialize="Sets up most of the needed fields as well as the environment itself.",
         reset="Resets the env and fields if the histories have been emptied.",
         before_episodes="Call the initialization method again.",
         do_step="Get actions from the agent and take a step through the env.",
         history="If the environment is done, we want to loop through the histories and empty them.",
         after_history="Once everything is processed, we set the next state to the current state for the next loop.")

# %%
source=Source(
    cbs=GymLoop(env_name='HumanoidPyBulletEnv-v0')
)
# Out:
# WalkerBase::__init__

# %%
source.show_loop()
# Out:
#  - after_create   : [GymLoop]
# Start Setup
#    - initialize     : [GymLoop]
# End Setup
#  - before_episodes: [GymLoop]
# Start Episodes
#    - reset          : [GymLoop]
#    - do_action      : []
#    - do_step        : [GymLoop]
#    - do_render      : []
#    - before_history : [GymLoop]
#    - history        : [GymLoop]
#    - after_history  : [GymLoop]
# End Episodes
#  - after_episodes : []

# %%
source.cbs[0].agent.cbs[0].action_executions
# Out:
# 0

# %%
d=None 
source=Source(
    cbs=GymLoop(env_name='HumanoidPyBulletEnv-v0',steps_delta=1,steps_count=1),
    persistent=True
)
for x,_ in zip(iter(source),range(50)): 
    if d is not None: d+=BD(x)
    else:             d=BD(x)
d.pandas(jupyter_nrows=300)
# Out:
# WalkerBase::__init__
# WalkerBase::__init__
# argv[0]=
# argv[0]=
#                    state            next_state   done  all_done  env_id  \
# 0   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 1   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 2   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 3   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 4   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 5   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 6   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 7   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 8   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 9   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 10  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 11  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 12  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 13  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 14  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 15  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 16  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 17  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 18  torch.Size([50, 44])  torch.Size([50, 44])   True      True       0
# 19  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 20  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 21  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 22  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 23  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 24  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 25  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 26  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 27  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 28  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 29  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 30  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 31  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 32  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 33  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 34  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 35  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 36  torch.Size([50, 44])  torch.Size([50, 44])   True      True       0
# 37  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 38  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 39  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 40  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 41  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 42  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 43  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 44  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 45  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 46  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 47  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 48  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 49  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
#
#     worker_id                action  episode_id  accum_rewards    reward  step
# 0           0  torch.Size([50, 17])           1       0.224209  0.224209     1
# 1           0  torch.Size([50, 17])           1      -1.036889 -1.261098     2
# 2           0  torch.Size([50, 17])           1      -2.243361 -1.206472     3
# 3           0  torch.Size([50, 17])           1      -2.652465 -0.409104     4
# 4           0  torch.Size([50, 17])           1      -3.891244 -1.238779     5
# 5           0  torch.Size([50, 17])           1      -6.191977 -2.300733     6
# 6           0  torch.Size([50, 17])           1      -8.738767 -2.546790     7
# 7           0  torch.Size([50, 17])           1      -9.420101 -0.681334     8
# 8           0  torch.Size([50, 17])           1     -11.450974 -2.030873     9
# 9           0  torch.Size([50, 17])           1     -12.823546 -1.372573    10
# 10          0  torch.Size([50, 17])           1     -15.530539 -2.706993    11
# 11          0  torch.Size([50, 17])           1     -16.861963 -1.331424    12
# 12          0  torch.Size([50, 17])           1     -18.683912 -1.821949    13
# 13          0  torch.Size([50, 17])           1     -20.680334 -1.996422    14
# 14          0  torch.Size([50, 17])           1     -20.565121  0.115214    15
# 15          0  torch.Size([50, 17])           1     -21.951899 -1.386778    16
# 16          0  torch.Size([50, 17])           1     -22.020096 -0.068197    17
# 17          0  torch.Size([50, 17])           1     -25.110855 -3.090760    18
# 18          0  torch.Size([50, 17])           1     -31.257797 -6.146942    19
# 19          0  torch.Size([50, 17])           2      -0.159001 -0.159001     1
# 20          0  torch.Size([50, 17])           2      -1.634214 -1.475212     2
# 21          0  torch.Size([50, 17])           2      -1.646052 -0.011839     3
# 22          0  torch.Size([50, 17])           2      -1.967394 -0.321342     4
# 23          0  torch.Size([50, 17])           2      -3.252871 -1.285477     5
# 24          0  torch.Size([50, 17])           2      -4.587852 -1.334981     6
# 25          0  torch.Size([50, 17])           2      -7.117702 -2.529850     7
# 26          0  torch.Size([50, 17])           2     -10.211718 -3.094016     8
# 27          0  torch.Size([50, 17])           2     -13.925764 -3.714046     9
# 28          0  torch.Size([50, 17])           2     -16.269648 -2.343884    10
# 29          0  torch.Size([50, 17])           2     -18.483387 -2.213740    11
# 30          0  torch.Size([50, 17])           2     -19.939098 -1.455711    12
# 31          0  torch.Size([50, 17])           2     -19.912306  0.026793    13
# 32          0  torch.Size([50, 17])           2     -20.192194 -0.279888    14
# 33          0  torch.Size([50, 17])           2     -22.648502 -2.456308    15
# 34          0  torch.Size([50, 17])           2     -23.457413 -0.808910    16
# 35          0  torch.Size([50, 17])           2     -24.081093 -0.623680    17
# 36          0  torch.Size([50, 17])           2     -27.927200 -3.846108    18
# 37          0  torch.Size([50, 17])           3       0.113291  0.113291     1
# 38          0  torch.Size([50, 17])           3       0.187320  0.074029     2
# 39          0  torch.Size([50, 17])           3       0.116449 -0.070870     3
# 40          0  torch.Size([50, 17])           3      -0.712331 -0.828780     4
# 41          0  torch.Size([50, 17])           3      -1.811917 -1.099586     5
# 42          0  torch.Size([50, 17])           3      -4.578411 -2.766494     6
# 43          0  torch.Size([50, 17])           3     -11.913105 -7.334694     7
# 44          0  torch.Size([50, 17])           3     -12.008710 -0.095605     8
# 45          0  torch.Size([50, 17])           3     -14.041313 -2.032603     9
# 46          0  torch.Size([50, 17])           3     -16.730339 -2.689026    10
# 47          0  torch.Size([50, 17])           3     -19.159153 -2.428814    11
# 48          0  torch.Size([50, 17])           3     -20.626999 -1.467846    12
# 49          0  torch.Size([50, 17])           3     -22.555603 -1.928604    13

# %%
d=None 
source=Source(
    cbs=GymLoop(env_name='HumanoidPyBulletEnv-v0',steps_delta=4,steps_count=2),
    persistent=False
)
for x,_ in zip(iter(source),range(50)): 
    if d is not None: d+=BD(x)
    else:             d=BD(x)
d.pandas(jupyter_nrows=300)
# Out:
# /home/fastrl_user/.local/lib/python3.8/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(
# WalkerBase::__init__
# WalkerBase::__init__
# argv[0]=
# argv[0]=
#                    state            next_state   done  all_done  env_id  \
# 0   torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 1   torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 2   torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 3   torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 4   torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 5   torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 6   torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 7   torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 8   torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 9   torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 10  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 11  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 12  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 13  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 14  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 15  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 16  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 17  torch.Size([93, 44])  torch.Size([93, 44])   True     False       0
# 18  torch.Size([93, 44])  torch.Size([93, 44])   True      True       0
# 19  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 20  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 21  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 22  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 23  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 24  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 25  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 26  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 27  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 28  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 29  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 30  torch.Size([93, 44])  torch.Size([93, 44])   True     False       0
# 31  torch.Size([93, 44])  torch.Size([93, 44])   True      True       0
# 32  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 33  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 34  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 35  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 36  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 37  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 38  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 39  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 40  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 41  torch.Size([93, 44])  torch.Size([93, 44])   True     False       0
# 42  torch.Size([93, 44])  torch.Size([93, 44])   True      True       0
# 43  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 44  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 45  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 46  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 47  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 48  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 49  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 50  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 51  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 52  torch.Size([93, 44])  torch.Size([93, 44])   True     False       0
# 53  torch.Size([93, 44])  torch.Size([93, 44])   True      True       0
# 54  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 55  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 56  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 57  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 58  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 59  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 60  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 61  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 62  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 63  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 64  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 65  torch.Size([93, 44])  torch.Size([93, 44])   True     False       0
# 66  torch.Size([93, 44])  torch.Size([93, 44])   True      True       0
# 67  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 68  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 69  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 70  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 71  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 72  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 73  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 74  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 75  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 76  torch.Size([93, 44])  torch.Size([93, 44])   True     False       0
# 77  torch.Size([93, 44])  torch.Size([93, 44])   True      True       0
# 78  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 79  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 80  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 81  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 82  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 83  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 84  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 85  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 86  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 87  torch.Size([93, 44])  torch.Size([93, 44])   True     False       0
# 88  torch.Size([93, 44])  torch.Size([93, 44])   True      True       0
# 89  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 90  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 91  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
# 92  torch.Size([93, 44])  torch.Size([93, 44])  False     False       0
#
#     worker_id                action  episode_id  accum_rewards    reward  step
# 0           0  torch.Size([93, 17])           1      -1.054040 -0.542324     3
# 1           0  torch.Size([93, 17])           1      -2.702384 -1.648345     4
# 2           0  torch.Size([93, 17])           1      -6.899103 -0.829668     7
# 3           0  torch.Size([93, 17])           1      -7.553154 -0.654051     8
# 4           0  torch.Size([93, 17])           1     -15.424783 -2.618064    11
# 5           0  torch.Size([93, 17])           1     -16.750374 -1.325592    12
# 6           0  torch.Size([93, 17])           1     -19.674646 -1.699259    15
# 7           0  torch.Size([93, 17])           1     -19.624516  0.050131    16
# 8           0  torch.Size([93, 17])           1     -25.014269 -3.887028    19
# 9           0  torch.Size([93, 17])           1     -26.500366 -1.486096    20
# 10          0  torch.Size([93, 17])           1     -30.334404  1.389526    23
# 11          0  torch.Size([93, 17])           1     -28.888805  1.445599    24
# 12          0  torch.Size([93, 17])           1     -34.481861 -3.050864    27
# 13          0  torch.Size([93, 17])           1     -35.420582 -0.938720    28
# 14          0  torch.Size([93, 17])           1     -37.514782 -0.707692    31
# 15          0  torch.Size([93, 17])           1     -36.168720  1.346062    32
# 16          0  torch.Size([93, 17])           1     -36.168720  1.346062    32
# 17          0  torch.Size([93, 17])           1     -39.259811 -3.091091    33
# 18          0  torch.Size([93, 17])           1     -39.259811 -3.091091    33
# 19          0  torch.Size([93, 17])           2      -3.984093 -0.694471     3
# 20          0  torch.Size([93, 17])           2      -3.539786  0.444307     4
# 21          0  torch.Size([93, 17])           2      -8.876405 -3.339910     7
# 22          0  torch.Size([93, 17])           2      -8.848678  0.027727     8
# 23          0  torch.Size([93, 17])           2     -11.757010 -0.643331    11
# 24          0  torch.Size([93, 17])           2     -12.410851 -0.653841    12
# 25          0  torch.Size([93, 17])           2     -16.194485 -0.923995    15
# 26          0  torch.Size([93, 17])           2     -17.867395 -1.672911    16
# 27          0  torch.Size([93, 17])           2     -26.137564 -3.396601    19
# 28          0  torch.Size([93, 17])           2     -27.626383 -1.488820    20
# 29          0  torch.Size([93, 17])           2     -30.643425 -1.678596    22
# 30          0  torch.Size([93, 17])           2     -35.616962 -4.973536    23
# 31          0  torch.Size([93, 17])           2     -35.616962 -4.973536    23
# 32          0  torch.Size([93, 17])           3      -1.992343 -0.385802     3
# 33          0  torch.Size([93, 17])           3      -4.498386 -2.506044     4
# 34          0  torch.Size([93, 17])           3     -12.829090 -3.051767     7
# 35          0  torch.Size([93, 17])           3     -14.829434 -2.000345     8
# 36          0  torch.Size([93, 17])           3     -22.672085 -1.828913    11
# 37          0  torch.Size([93, 17])           3     -24.235409 -1.563323    12
# 38          0  torch.Size([93, 17])           3     -26.851128 -1.094098    15
# 39          0  torch.Size([93, 17])           3     -28.073902 -1.222775    16
# 40          0  torch.Size([93, 17])           3     -29.060274 -0.986372    17
# 41          0  torch.Size([93, 17])           3     -32.763111 -3.702835    18
# 42          0  torch.Size([93, 17])           3     -32.763111 -3.702835    18
# 43          0  torch.Size([93, 17])           4      -1.055471 -0.657142     3
# 44          0  torch.Size([93, 17])           4      -1.795626 -0.740156     4
# 45          0  torch.Size([93, 17])           4      -3.263175 -0.512509     7
# 46          0  torch.Size([93, 17])           4      -5.308920 -2.045745     8
# 47          0  torch.Size([93, 17])           4     -14.199278 -6.892894    11
# 48          0  torch.Size([93, 17])           4     -16.661377 -2.462098    12
# 49          0  torch.Size([93, 17])           4     -23.404762 -2.716537    15
# 50          0  torch.Size([93, 17])           4     -24.973028 -1.568266    16
# 51          0  torch.Size([93, 17])           4     -25.197664  0.641098    18
# 52          0  torch.Size([93, 17])           4     -28.686319 -3.488655    19
# 53          0  torch.Size([93, 17])           4     -28.686319 -3.488655    19
# 54          0  torch.Size([93, 17])           5      -0.530288  0.312611     3
# 55          0  torch.Size([93, 17])           5      -1.350622 -0.820334     4
# 56          0  torch.Size([93, 17])           5      -7.748623 -3.014027     7
# 57          0  torch.Size([93, 17])           5      -8.455316 -0.706693     8
# 58          0  torch.Size([93, 17])           5     -16.177582 -3.486815    11
# 59          0  torch.Size([93, 17])           5     -17.903538 -1.725955    12
# 60          0  torch.Size([93, 17])           5     -24.232111 -1.451163    15
# 61          0  torch.Size([93, 17])           5     -25.305227 -1.073117    16
# 62          0  torch.Size([93, 17])           5     -36.253319 -3.493410    19
# 63          0  torch.Size([93, 17])           5     -36.599155 -0.345835    20
# 64          0  torch.Size([93, 17])           5     -36.599155 -0.345835    20
# 65          0  torch.Size([93, 17])           5     -40.883301 -4.284144    21
# 66          0  torch.Size([93, 17])           5     -40.883301 -4.284144    21
# 67          0  torch.Size([93, 17])           6      -6.669263 -2.313206     3
# 68          0  torch.Size([93, 17])           6      -9.118885 -2.449622     4
# 69          0  torch.Size([93, 17])           6     -18.239443 -3.222784     7
# 70          0  torch.Size([93, 17])           6     -18.356726 -0.117282     8
# 71          0  torch.Size([93, 17])           6     -25.142986 -2.604519    11
# 72          0  torch.Size([93, 17])           6     -28.779047 -3.636060    12
# 73          0  torch.Size([93, 17])           6     -34.139397 -1.274438    15
# 74          0  torch.Size([93, 17])           6     -36.424839 -2.285443    16
# 75          0  torch.Size([93, 17])           6     -39.301987 -0.383274    18
# 76          0  torch.Size([93, 17])           6     -42.920143 -3.618156    19
# 77          0  torch.Size([93, 17])           6     -42.920143 -3.618156    19
# 78          0  torch.Size([93, 17])           7      -2.602334 -0.080707     3
# 79          0  torch.Size([93, 17])           7      -3.686775 -1.084440     4
# 80          0  torch.Size([93, 17])           7     -10.376181 -4.171218     7
# 81          0  torch.Size([93, 17])           7     -15.922807 -5.546626     8
# 82          0  torch.Size([93, 17])           7     -26.705441 -3.935713    11
# 83          0  torch.Size([93, 17])           7     -29.160206 -2.454765    12
# 84          0  torch.Size([93, 17])           7     -34.693718 -1.503091    15
# 85          0  torch.Size([93, 17])           7     -35.026680 -0.332963    16
# 86          0  torch.Size([93, 17])           7     -37.237690 -1.484164    18
# 87          0  torch.Size([93, 17])           7     -42.238441 -5.000752    19
# 88          0  torch.Size([93, 17])           7     -42.238441 -5.000752    19
# 89          0  torch.Size([93, 17])           8      -3.352186 -0.002168     3
# 90          0  torch.Size([93, 17])           8      -6.313209 -2.961022     4
# 91          0  torch.Size([93, 17])           8     -10.984173 -1.058541     7
# 92          0  torch.Size([93, 17])           8     -10.390368  0.593804     8

# %%
# export
class FirstLastTfm(Transform):
    def __init__(self,gamma):
        store_attr()
        super().__init__()
        
        
    def encodes(self,o):
#         print('encoding')
        source,history=o['source'],o['history']
#         print(source,history,o)
        element=history[0]
        if history.bs()!=1:
            remainder=history[1:]
            reward=element['reward']
            for e in reversed(remainder['reward']):
                reward*=self.gamma
                reward+=e
            element['reward']=reward
            element['next_state']=history[-1]['next_state']
            element['done']=history[-1]['done']
            
#         print(source,element)
        return {'source':source,'history':element}
    
class FirstLast(LoopCallback):
    _methods=source_events
    _default='source'
                
    def __init__(self,gamma=0.99): store_attr()
    def before_episodes(self): self('initialize')    
    def initialize(self):
        if isinstance(self.source.return_fn,Pipeline):
            self.source.return_fn.add(FirstLastTfm(self.gamma))
        else:
            self.source.return_fn=Pipeline([self.source.return_fn,FirstLastTfm(self.gamma)])

# %%
source.show_loop()
# Out:
#  - after_create   : [GymLoop]
# Start Setup
#    - initialize     : [GymLoop]
# End Setup
#  - before_episodes: [GymLoop]
# Start Episodes
#    - reset          : [GymLoop]
#    - do_action      : []
#    - do_step        : [GymLoop]
#    - do_render      : []
#    - before_history : [GymLoop]
#    - history        : [GymLoop]
#    - after_history  : [GymLoop]
# End Episodes
#  - after_episodes : []

# %%
d=None 
source=Source(
    cbs=[GymLoop(env_name='CartPole-v1',steps_delta=1,steps_count=1),FirstLast]
)
for x,_ in zip(iter(source),range(50)): 
    if d is not None: d+=BD(x)
    else:             d=BD(x)
d.pandas(jupyter_nrows=40)
# Out:
#                   state           next_state   done  all_done  env_id  \
# 0   torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
# 1   torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
# 2   torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
# 3   torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
# 4   torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
# ..                  ...                  ...    ...       ...     ...
# 45  torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
# 46  torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
# 47  torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
# 48  torch.Size([50, 4])  torch.Size([50, 4])   True      True       0
# 49  torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
#
#     worker_id  action  episode_id  accum_rewards  reward  step
# 0           0     0.0           1            1.0     1.0     1
# 1           0     1.0           1            2.0     1.0     2
# 2           0     1.0           1            3.0     1.0     3
# 3           0     1.0           1            4.0     1.0     4
# 4           0     1.0           1            5.0     1.0     5
# ..        ...     ...         ...            ...     ...   ...
# 45          0     1.0           2           35.0     1.0    35
# 46          0     1.0           2           36.0     1.0    36
# 47          0     0.0           2           37.0     1.0    37
# 48          0     1.0           2           38.0     1.0    38
# 49          0     0.0           3            1.0     1.0     1
#
# [50 rows x 11 columns]

# %%
d=None 
source=Source(
    cbs=[GymLoop(env_name='CartPole-v1',steps_delta=1,steps_count=4),FirstLast]
)
for x,_ in zip(iter(source),range(50)): 
    if d is not None: d+=BD(x)
    else:             d=BD(x)
d.pandas(mu=True,jupyter_nrows=300)[['state_mu','next_state_mu','done']]
# Out:
#     state_mu  next_state_mu   done
# 0  -0.004724       0.031226  False
# 1   0.016113       0.004767  False
# 2  -0.011280      -0.021490  False
# 3   0.009797      -0.047971  False
# 4   0.031226      -0.075111  False
# 5   0.004767      -0.054650  False
# 6  -0.021490      -0.083452  False
# 7  -0.047971      -0.113395  False
# 8  -0.075111      -0.096496  False
# 9  -0.054650      -0.129051  False
# 10 -0.083452      -0.163235  False
# 11 -0.113395      -0.151896  False
# 12 -0.096496      -0.142658  False
# 13 -0.129051      -0.135178  False
# 14 -0.163235      -0.129102  False
# 15 -0.151896      -0.124063   True
# 16 -0.142658      -0.124063   True
# 17 -0.135178      -0.124063   True
# 18 -0.129102      -0.124063   True
# 19  0.009831       0.022323  False
# 20  0.036250       0.050839  False
# 21  0.063230       0.080009  False
# 22  0.042507       0.110270  False
# 23  0.022323       0.093693  False
# 24  0.050839       0.126469  False
# 25  0.080009       0.160830  False
# 26  0.110270       0.149685  False
# 27  0.093693       0.140597  False
# 28  0.126469       0.179558  False
# 29  0.160830       0.220277   True
# 30  0.149685       0.220277   True
# 31  0.140597       0.220277   True
# 32  0.179558       0.220277   True
# 33  0.040876       0.000790  False
# 34  0.018962      -0.022483  False
# 35  0.045397       0.001787  False
# 36  0.023271      -0.023410  False
# 37  0.000790      -0.049844  False
# 38 -0.022483      -0.077949  False
# 39  0.001787      -0.108148  False
# 40 -0.023410      -0.092577  False
# 41 -0.049844      -0.079451  False
# 42 -0.077949      -0.115627  False
# 43 -0.108148      -0.153940  False
# 44 -0.092577      -0.194747   True
# 45 -0.079451      -0.194747   True
# 46 -0.115627      -0.194747   True
# 47 -0.153940      -0.194747   True
# 48 -0.008585      -0.070245  False
# 49 -0.034913      -0.100378  False

# %%
d=None 
source=Source(
    cbs=[GymLoop(env_name='HumanoidPyBulletEnv-v0',steps_delta=3),FirstLast]
)
for x,_ in zip(iter(source),range(50)): 
    if d is not None: d+=BD(x)
    else:             d=BD(x)
d.pandas(jupyter_nrows=300)
# Out:
# /home/fastrl_user/.local/lib/python3.8/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(
# WalkerBase::__init__
# WalkerBase::__init__
# WalkerBase::__init__
# argv[0]=
# argv[0]=
#                    state            next_state   done  all_done  env_id  \
# 0   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 1   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 2   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 3   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 4   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 5   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 6   torch.Size([50, 44])  torch.Size([50, 44])   True      True       0
# 7   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 8   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 9   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 10  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 11  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 12  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 13  torch.Size([50, 44])  torch.Size([50, 44])   True      True       0
# 14  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 15  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 16  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 17  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 18  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 19  torch.Size([50, 44])  torch.Size([50, 44])   True      True       0
# 20  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 21  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 22  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 23  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 24  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 25  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 26  torch.Size([50, 44])  torch.Size([50, 44])   True      True       0
# 27  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 28  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 29  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 30  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 31  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 32  torch.Size([50, 44])  torch.Size([50, 44])   True      True       0
# 33  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 34  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 35  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 36  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 37  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 38  torch.Size([50, 44])  torch.Size([50, 44])   True      True       0
# 39  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 40  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 41  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 42  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 43  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 44  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 45  torch.Size([50, 44])  torch.Size([50, 44])   True      True       0
# 46  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 47  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 48  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 49  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
#
#     worker_id                action  episode_id  accum_rewards    reward  step
# 0           0  torch.Size([50, 17])           1     -10.466591 -3.129092     3
# 1           0  torch.Size([50, 17])           1     -15.341833 -1.188536     6
# 2           0  torch.Size([50, 17])           1     -23.888718 -2.391367     9
# 3           0  torch.Size([50, 17])           1     -34.182518 -2.666425    12
# 4           0  torch.Size([50, 17])           1     -42.651329 -1.740501    15
# 5           0  torch.Size([50, 17])           1     -53.223206 -3.097689    18
# 6           0  torch.Size([50, 17])           1     -60.937790 -6.024866    20
# 7           0  torch.Size([50, 17])           2     -12.035754 -4.848444     3
# 8           0  torch.Size([50, 17])           2     -17.088457 -1.554627     6
# 9           0  torch.Size([50, 17])           2     -22.791599 -1.265003     9
# 10          0  torch.Size([50, 17])           2     -23.833071 -0.185288    12
# 11          0  torch.Size([50, 17])           2     -30.792171 -3.633424    15
# 12          0  torch.Size([50, 17])           2     -36.892895 -2.455958    18
# 13          0  torch.Size([50, 17])           2     -42.593063 -5.700169    19
# 14          0  torch.Size([50, 17])           3      -5.039013 -1.659217     3
# 15          0  torch.Size([50, 17])           3     -17.647131 -5.122095     6
# 16          0  torch.Size([50, 17])           3     -20.613611 -1.367492     9
# 17          0  torch.Size([50, 17])           3     -29.437246 -5.728907    12
# 18          0  torch.Size([50, 17])           3     -35.115334 -2.941422    15
# 19          0  torch.Size([50, 17])           3     -41.086048 -3.418911    18
# 20          0  torch.Size([50, 17])           4      -4.245522 -3.406236     3
# 21          0  torch.Size([50, 17])           4      -8.454030  0.086686     6
# 22          0  torch.Size([50, 17])           4     -12.625296 -0.668282     9
# 23          0  torch.Size([50, 17])           4     -13.695427  0.185921    12
# 24          0  torch.Size([50, 17])           4     -14.971830 -0.018389    15
# 25          0  torch.Size([50, 17])           4     -15.403198  0.146364    18
# 26          0  torch.Size([50, 17])           4     -21.580807 -3.320113    21
# 27          0  torch.Size([50, 17])           5      -2.806898 -0.467919     3
# 28          0  torch.Size([50, 17])           5     -15.895551 -1.434428     6
# 29          0  torch.Size([50, 17])           5     -20.239458 -0.648024     9
# 30          0  torch.Size([50, 17])           5     -22.539848 -0.294408    12
# 31          0  torch.Size([50, 17])           5     -27.009743 -1.725241    15
# 32          0  torch.Size([50, 17])           5     -33.864178 -4.169717    18
# 33          0  torch.Size([50, 17])           6      -2.629019 -2.543620     3
# 34          0  torch.Size([50, 17])           6      -7.680727 -2.600699     6
# 35          0  torch.Size([50, 17])           6     -13.262449 -2.782605     9
# 36          0  torch.Size([50, 17])           6     -17.245853 -1.158971    12
# 37          0  torch.Size([50, 17])           6     -20.127718 -0.823819    15
# 38          0  torch.Size([50, 17])           6     -27.486616 -5.707702    18
# 39          0  torch.Size([50, 17])           7      -3.240240 -1.753200     3
# 40          0  torch.Size([50, 17])           7     -11.891174 -1.797556     6
# 41          0  torch.Size([50, 17])           7     -17.265911 -1.552301     9
# 42          0  torch.Size([50, 17])           7     -24.391708 -3.303290    12
# 43          0  torch.Size([50, 17])           7     -25.978971 -0.330943    15
# 44          0  torch.Size([50, 17])           7     -27.646544 -0.769039    18
# 45          0  torch.Size([50, 17])           7     -31.563299 -3.957856    20
# 46          0  torch.Size([50, 17])           8      -0.662107 -0.090655     3
# 47          0  torch.Size([50, 17])           8      -3.451362 -1.470447     6
# 48          0  torch.Size([50, 17])           8     -10.663258 -1.954481     9
# 49          0  torch.Size([50, 17])           8     -13.822918 -0.044883    12

# %%
# export
def show_source(src,iters=50):
    from IPython import display
    import PIL.Image
    
    for x,_ in zip(iter(src),range(iters)):
        for _img in x['image'].numpy():
            display.clear_output(wait=True)
            display.display(PIL.Image.fromarray(_img))

# %%
# %matplotlib inline

# %%
source=Source(
    cbs=[GymLoop(env_name='HumanoidPyBulletEnv-v0',mode='rgb_array',steps_delta=3),FirstLast]
)
show_source(source,50)
# Out:
# <PIL.Image.Image image mode=RGB size=320x240 at 0x7FA3134102B0>

# %%
source=Source(
    cbs=[GymLoop(env_name='CartPole-v1',mode='rgb_array',steps_delta=3),FirstLast]
)
show_source(source,50)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7FA313374EE0>

# %%
# export
class ResReduce(LoopCallback):
    _methods=source_events
    _default='source'
                
    def __init__(self,
                 reduce_by=2 # The amount to reduce the `image` resolution by e.g.: 400x400 -> 200x200 if default is used.
                ): 
        "Reduces the image field in a loop by `reduce_by` and assumes image is format BxWxHxC or BxHxWxC"
        store_attr()
    def before_episodes(self): self('initialize')    
    def initialize(self):
        if 'image' not in self.data_fields:
            warn('Since `image` not in self.data_fields, no image reduction will be attempted!')
            
    def do_step(self):
        if 'image' in self.data_fields:
            self.source.image=self.source.image[:,::self.reduce_by,::self.reduce_by,:]

# %%
source=Source(
    cbs=[GymLoop(env_name='CartPole-v1',mode='rgb_array',steps_delta=3),ResReduce(reduce_by=3)]
)
show_source(source,50)
# Out:
# <PIL.Image.Image image mode=RGB size=200x134 at 0x7FA3133697F0>

# %% [markdown]
# ### Metrics

# %%
# export
class Reward(Metric):
    order=30
    reward=None
    rolling_reward_n=100
    keep_rewards=False
    counter=0
    
    def __init__(self,writer:SummaryWriter=None): store_attr()
 
    def reset(self):
        if self.reward is None: self.reward=deque(maxlen=self.rolling_reward_n)
            
    def accumulate(self,learn):
        xb=learn.xb[0]
        self.counter+=1
        if xb['all_done'].sum()>0:
            final_rewards=to_detach(xb['accum_rewards'][xb['all_done']]).reshape(-1,).numpy().tolist()

            for r in final_rewards: 
                self.reward.append(r)
                if self.writer is not None: self.writer.add_scalar('reward',r,self.counter)
                
    @property
    def value(self): return np.average(self.reward) if len(self.reward)>0 else 0

# %%
# export
class NEpisodes(Metric):
    order=30
    n_episodes=None

    def reset(self):
        if self.n_episodes is None: self.n_episodes=0
            
    def accumulate(self,learn):
        xb=learn.xb[0]
        if xb['all_done'].sum()>0:
            new_episodes=torch.unique(to_detach(xb['episode_id'][xb['all_done']]))
            self.n_episodes+=len(new_episodes)
                
                
    @property
    def value(self): return self.n_episodes

# %%
# export 
def fake_gym_learner(source,n=1000,bs=1,num_workers=0,**kwargs):
    from torch.nn import Linear

    class FakeModel(Module):
        def __init__(self):  self.fc=Linear(5,5)
        def forward(self,x): return x

    block=SourceDataBlock()
    dls=block.dataloaders([source],n=n,bs=bs,num_workers=num_workers,verbose=False)
    return Learner(dls,FakeModel(),metrics=[Reward,NEpisodes],loss_func=lambda o: 0.5,**kwargs)

# %%
source=Source(cbs=[GymLoop(env_name='CartPole-v1'),FirstLast],persistent=True)
learn=fake_gym_learner(source,bs=64)
learn.fit(4)
# Out:
# Could not do one pass in your dataloader, there is something wrong in it
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>train_reward</th>
#       <th>train_n_episodes</th>
#       <th>valid_loss</th>
#       <th>valid_reward</th>
#       <th>valid_n_episodes</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.000000</td>
#       <td>23.600000</td>
#       <td>40</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>23.597561</td>
#       <td>82</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>22.960000</td>
#       <td>127</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>21.670000</td>
#       <td>175</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_eq(source.cbs[0].agent.cbs[0].action_executions,4000)

# %% [markdown]
# ## Export

# %%
# hide
from fastcore.imports import in_colab

# Since colab still requires tornado<6, we don't want to import nbdev if we don't have to
if not in_colab():
    from nbdev.export import *
    from nbdev.export2html import *
    from nbverbose.cli import *
    make_readme()
    notebook2script(silent=True)
# Out:
# converting /home/fastrl_user/fastrl/nbs/index.ipynb to README.md
# Converted 00_core.ipynb.
# Converted 00_nbdev_extension.ipynb.
# Converted 03_callback.core.ipynb.
# Converted 04_agent.ipynb.
# Converted 05_data.test_async.ipynb.
# Converted 05a_data.block.ipynb.
# Converted 05b_data.gym.ipynb.
# Converted 06a_memory.experience_replay.ipynb.
# Converted 06f_memory.tensorboard.ipynb.
# Converted 10a_agents.dqn.core.ipynb.
# Converted 10b_agents.dqn.targets.ipynb.
# Converted 10c_agents.dqn.double.ipynb.
# Converted 10d_agents.dqn.dueling.ipynb.
# Converted 10e_agents.dqn.categorical.ipynb.
# Converted 11a_agents.policy_gradient.ppo.ipynb.
# Converted 20_test_utils.ipynb.
# Converted index.ipynb.
# Converted nbdev_template.ipynb.
# converting: /home/fastrl_user/fastrl/nbs/05b_data.gym.ipynb
# converting: /home/fastrl_user/fastrl/nbs/00_core.ipynb
