# %%
#hide
#skip
# %config Completer.use_jedi = False
# upgrade fastrl on colab
! [ -e /content ] && pip install -Uqq fastrl['dev'] pyvirtualdisplay && \
                     apt-get install -y xvfb python-opengl > /dev/null 2>&1 
# NOTE: IF YOU SEE VERSION ERRORS, IT IS SAFE TO IGNORE THEM. COLAB IS BEHIND IN SOME OF THE PACKAGE VERSIONS

# %%
# hide
from fastcore.imports import in_colab
# Since colab still requires tornado<6, we don't want to import nbdev if we don't have to
if not in_colab():
    from nbdev.showdoc import *
    from nbdev.imports import *
    if not os.environ.get("IN_TEST", None):
#         assert IN_NOTEBOOK
        assert not IN_COLAB
        assert IN_IPYTHON
else:
    # Virtual display is needed for colab
    from pyvirtualdisplay import Display
    display = Display(visible=0, size=(400, 300))
    display.start()

# %%
# default_exp data.gym

# %%
# export
# Python native modules
import os
from collections import deque
from copy import deepcopy
from time import sleep
from typing import *
# Third party libs
from fastcore.all import *
from fastai.torch_basics import *
from fastai.data.all import *
from fastai.basics import *
from fastai.callback.all import *
from torch.utils.data import Dataset
from torch import nn
import torch
import gym
import pybulletgym
import numpy as np
# Local modules
from fastrl.core import *
from fastrl.callback.core import *
from fastrl.data.block_simple import *
from fastrl.agent import *

# %% [markdown]
# # Data Block Gym
# > openai gym sources

# %% [markdown]
# ## GymSource
# > The base iterable used for iterating through environments.

# %%
# Source().show_loop()

# %%
# export
class ReturnHistory(Transform):
    def encodes(self,o:dict):
        source,data=o['source'],o['history']
        history=sum(source.histories)
        if len(source.histories)==1 and sum(history['done'])>0:
            source.all_done=TensorBatch([[True]])
            history['all_done']=TensorBatch([[True]])
        source.histories.popleft()
        return {'source':source,'history':history}

# %%
# export
class TstCallback(AgentCallback):
    def __init__(self,action_space=None,constant=None): store_attr()
    def before_noise(self):
        bs=self.experience['state'].shape[0]
        self.agent.action=Tensor([[self.constant] if self.constant is not None else 
                                   self.action_space.sample() 
                                   for _ in range(bs)])
        self.agent.experience=D(merge(self.experience,{'random_action':np.random.randint(0,3,(bs,1))}))

def np_type_cast(a,dtype): return a.astype(dtype)
        
class GymLoop(LoopCallback):
    _methods=source_events
    _default='source'
    def __init__(self,env_name:str,agent=None,mode=None,
                 steps_count:int=1,steps_delta:int=1,seed:int=None,
                 worker_id:int=0,dtype=None): 
        store_attr()
        
    def initialize(self):
        self.source.histories=deque(maxlen=self.steps_count)    
        self.source.return_fn=Pipeline([ReturnHistory])
        if self.mode!='rgb_array': self.source.ignore_fields.append('image')
        self.source.worker_id=get_worker_info()
        self.source.worker_id=TensorBatch([[getattr(self.worker_id,'id',0)]])
        
        self.source.env=gym.make(self.env_name)
        if isinstance(self.env.action_space,gym.spaces.Discrete): 
            self.dtype=int
        elif isinstance(self.env.action_space,gym.spaces.Box):    
            if issubclass(self.env.action_space.dtype.type,(float,np.floating)): 
                self.dtype=partial(np_type_cast,dtype=float)
            if issubclass(self.env.action_space.dtype.type,(int,np.integer)): 
                self.dtype=partial(np_type_cast,dtype=int)
        else:
            self.dtype=float
        
        self.agent=ifnone(self.agent,Agent(cbs=TstCallback(action_space=self.env.action_space)))
        self.source.episode_id=TensorBatch([[0]])
        self.source.done=TensorBatch([[True]])
        self.source.all_done=TensorBatch([[True]])
    
    def reset(self):
        if len(self.histories)==0 and sum(self.all_done)>=1:
            self.source.env_id=TensorBatch([[0]])
            self.source.reward=TensorBatch([[0.0]])
            self.source.episode_id+=1
            self.source.accum_rewards=TensorBatch([[0.0]])
            self.source.step=TensorBatch([[0]])
            self.source.env_id=TensorBatch([[0]])
            self.source.done=TensorBatch([[False]])
            self.source.all_done=TensorBatch([[False]])
            self.source.env.seed(self.seed)
            self.source.state=TensorBatch(self.env.reset()).unsqueeze(0)

    def before_episodes(self): self('initialize')
        
    def do_step(self):
        action,experience=self.agent.do_action(**self.data())
        for k,v in experience.items(): 
            if v is not None: setattr(self.source,k,TensorBatch(v))
        self.source.action=TensorBatch(action)
        step_action=self.action.numpy()[0]
        next_state,reward,done,_=self.env.step(self.dtype(step_action))
        self.source.next_state=TensorBatch(next_state).unsqueeze(0)
        self.source.reward=TensorBatch([[reward]])
        self.source.accum_rewards+=reward
        self.source.done=TensorBatch([[done]])
        self.source.step+=1
    
    def before_history(self):
        self.source.skip_history_return=False
        self.histories.append(deepcopy(self.data()))

        if self.done.sum().item()<1:
            self.source.skip_history_return=len(self.histories)<self.steps_count or \
                                            int(self.step.item())%self.steps_delta!=0
    
    def history(self):
        if sum(self.done)>0 and len(self.histories)>1 and self.steps_count>1: 
            self.source.loop_history_yield=True
            
    def after_history(self):
        self.source.state=self.source.next_state
            
            
add_docs(GymLoop,"Handles iterating through single openai gym (and varients).",
         before_history="""Primarily appends `self.data()` to `self.histories` however it also...
         
         If the number of elements in `self.histories` is empty, or about to be empty, and
         `self.done==True` it sets the `self.all_done` field.
         
         If `self.done==True` also determine if we should skip returning a history.
         Mainly if we need to accumulate the histories first.
         """,
         initialize="Sets up most of the needed fields as well as the environment itself.",
         reset="Resets the env and fields if the histories have been emptied.",
         before_episodes="Call the initialization method again.",
         do_step="Get actions from the agent and take a step through the env.",
         history="If the environment is done, we want to loop through the histories and empty them.",
         after_history="Once everything is processed, we set the next state to the current state for the next loop.")

# %%
source=Source(
    cbs=GymLoop(env_name='HumanoidPyBulletEnv-v0')
)
# Out:
# WalkerBase::__init__
# pybullet build time: Aug  7 2021 06:42:21
# /home/fastrl_user/.local/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
source.show_loop()
# Out:
#  - after_create   : [GymLoop]
# Start Setup
#    - initialize     : [GymLoop]
# End Setup
#  - before_episodes: [GymLoop]
# Start Episodes
#    - reset          : [GymLoop]
#    - do_action      : []
#    - do_step        : [GymLoop]
#    - do_render      : []
#    - before_history : [GymLoop]
#    - history        : [GymLoop]
#    - after_history  : [GymLoop]
# End Episodes
#  - after_episodes : []

# %%
d=None 
source=Source(
    cbs=GymLoop(env_name='HumanoidPyBulletEnv-v0',steps_delta=4,steps_count=2)
)
for x,_ in zip(iter(source),range(50)): 
    if d is not None: d+=BD(x)
    else:             d=BD(x)
d.pandas(jupyter_nrows=300)
# Out:
# WalkerBase::__init__
# WalkerBase::__init__
#                    state            next_state   done  all_done  env_id  \
# 0   torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 1   torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 2   torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 3   torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 4   torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 5   torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 6   torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 7   torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 8   torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 9   torch.Size([92, 44])  torch.Size([92, 44])   True     False       0
# 10  torch.Size([92, 44])  torch.Size([92, 44])   True      True       0
# 11  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 12  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 13  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 14  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 15  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 16  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 17  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 18  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 19  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 20  torch.Size([92, 44])  torch.Size([92, 44])   True     False       0
# 21  torch.Size([92, 44])  torch.Size([92, 44])   True      True       0
# 22  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 23  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 24  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 25  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 26  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 27  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 28  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 29  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 30  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 31  torch.Size([92, 44])  torch.Size([92, 44])   True     False       0
# 32  torch.Size([92, 44])  torch.Size([92, 44])   True      True       0
# 33  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 34  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 35  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 36  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 37  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 38  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 39  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 40  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 41  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 42  torch.Size([92, 44])  torch.Size([92, 44])   True     False       0
# 43  torch.Size([92, 44])  torch.Size([92, 44])   True      True       0
# 44  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 45  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 46  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 47  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 48  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 49  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 50  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 51  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 52  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 53  torch.Size([92, 44])  torch.Size([92, 44])   True     False       0
# 54  torch.Size([92, 44])  torch.Size([92, 44])   True      True       0
# 55  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 56  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 57  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 58  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 59  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 60  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 61  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 62  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 63  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 64  torch.Size([92, 44])  torch.Size([92, 44])   True     False       0
# 65  torch.Size([92, 44])  torch.Size([92, 44])   True      True       0
# 66  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 67  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 68  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 69  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 70  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 71  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 72  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 73  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 74  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 75  torch.Size([92, 44])  torch.Size([92, 44])   True     False       0
# 76  torch.Size([92, 44])  torch.Size([92, 44])   True      True       0
# 77  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 78  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 79  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 80  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 81  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 82  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 83  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 84  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 85  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 86  torch.Size([92, 44])  torch.Size([92, 44])   True     False       0
# 87  torch.Size([92, 44])  torch.Size([92, 44])   True      True       0
# 88  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 89  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 90  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
# 91  torch.Size([92, 44])  torch.Size([92, 44])  False     False       0
#
#     worker_id                action  episode_id  accum_rewards    reward  step
# 0           0  torch.Size([92, 17])           1      -2.482699 -0.382659     3
# 1           0  torch.Size([92, 17])           1      -2.965973 -0.483274     4
# 2           0  torch.Size([92, 17])           1      -6.227715 -1.232602     7
# 3           0  torch.Size([92, 17])           1      -9.399419 -3.171704     8
# 4           0  torch.Size([92, 17])           1     -15.394580 -2.760100    11
# 5           0  torch.Size([92, 17])           1     -16.669701 -1.275120    12
# 6           0  torch.Size([92, 17])           1     -23.444479 -3.891031    15
# 7           0  torch.Size([92, 17])           1     -25.258101 -1.813621    16
# 8           0  torch.Size([92, 17])           1     -26.153095 -0.349922    19
# 9           0  torch.Size([92, 17])           1     -29.132420 -2.979325    20
# 10          0  torch.Size([92, 17])           1     -29.132420 -2.979325    20
# 11          0  torch.Size([92, 17])           2      -1.639283 -0.817688     3
# 12          0  torch.Size([92, 17])           2      -3.775147 -2.135865     4
# 13          0  torch.Size([92, 17])           2      -7.669006 -0.572928     7
# 14          0  torch.Size([92, 17])           2      -8.561363 -0.892358     8
# 15          0  torch.Size([92, 17])           2     -10.589720 -0.028115    11
# 16          0  torch.Size([92, 17])           2     -10.233586  0.356134    12
# 17          0  torch.Size([92, 17])           2     -15.732047 -0.729358    15
# 18          0  torch.Size([92, 17])           2     -16.966900 -1.234854    16
# 19          0  torch.Size([92, 17])           2     -18.056194 -1.202871    18
# 20          0  torch.Size([92, 17])           2     -22.699017 -4.642823    19
# 21          0  torch.Size([92, 17])           2     -22.699017 -4.642823    19
# 22          0  torch.Size([92, 17])           3      -6.576355 -1.307141     3
# 23          0  torch.Size([92, 17])           3      -7.485957 -0.909602     4
# 24          0  torch.Size([92, 17])           3      -9.734274 -1.048234     7
# 25          0  torch.Size([92, 17])           3     -10.017443 -0.283168     8
# 26          0  torch.Size([92, 17])           3     -15.369820 -1.899969    11
# 27          0  torch.Size([92, 17])           3     -15.881198 -0.511378    12
# 28          0  torch.Size([92, 17])           3     -18.918468 -0.827064    15
# 29          0  torch.Size([92, 17])           3     -20.598169 -1.679701    16
# 30          0  torch.Size([92, 17])           3     -22.103979 -1.505810    17
# 31          0  torch.Size([92, 17])           3     -24.645180 -2.541201    18
# 32          0  torch.Size([92, 17])           3     -24.645180 -2.541201    18
# 33          0  torch.Size([92, 17])           4      -4.252063 -2.746854     3
# 34          0  torch.Size([92, 17])           4      -4.628987 -0.376924     4
# 35          0  torch.Size([92, 17])           4      -9.677666 -1.134668     7
# 36          0  torch.Size([92, 17])           4     -10.231515 -0.553849     8
# 37          0  torch.Size([92, 17])           4     -13.049326 -0.162362    11
# 38          0  torch.Size([92, 17])           4     -15.954521 -2.905195    12
# 39          0  torch.Size([92, 17])           4     -18.756729 -0.179503    15
# 40          0  torch.Size([92, 17])           4     -21.503567 -2.746837    16
# 41          0  torch.Size([92, 17])           4     -26.563345 -5.028866    18
# 42          0  torch.Size([92, 17])           4     -30.878666 -4.315321    19
# 43          0  torch.Size([92, 17])           4     -30.878666 -4.315321    19
# 44          0  torch.Size([92, 17])           5      -2.309247 -0.623999     3
# 45          0  torch.Size([92, 17])           5      -4.839674 -2.530428     4
# 46          0  torch.Size([92, 17])           5     -10.362645 -0.276421     7
# 47          0  torch.Size([92, 17])           5     -12.596140 -2.233495     8
# 48          0  torch.Size([92, 17])           5     -13.603881 -0.710868    11
# 49          0  torch.Size([92, 17])           5     -13.150122  0.453759    12
# 50          0  torch.Size([92, 17])           5     -15.876337 -2.821546    15
# 51          0  torch.Size([92, 17])           5     -14.985149  0.891188    16
# 52          0  torch.Size([92, 17])           5     -15.147312 -1.292642    19
# 53          0  torch.Size([92, 17])           5     -20.380424 -5.233113    20
# 54          0  torch.Size([92, 17])           5     -20.380424 -5.233113    20
# 55          0  torch.Size([92, 17])           6       0.059834  0.142235     3
# 56          0  torch.Size([92, 17])           6      -0.069864 -0.129698     4
# 57          0  torch.Size([92, 17])           6      -2.575794  0.361024     7
# 58          0  torch.Size([92, 17])           6      -3.500016 -0.924222     8
# 59          0  torch.Size([92, 17])           6     -11.401312 -5.069597    11
# 60          0  torch.Size([92, 17])           6     -16.314013 -4.912700    12
# 61          0  torch.Size([92, 17])           6     -23.150349 -2.150447    15
# 62          0  torch.Size([92, 17])           6     -24.907024 -1.756676    16
# 63          0  torch.Size([92, 17])           6     -28.685297 -1.442707    19
# 64          0  torch.Size([92, 17])           6     -33.465027 -4.779729    20
# 65          0  torch.Size([92, 17])           6     -33.465027 -4.779729    20
# 66          0  torch.Size([92, 17])           7      -2.474712 -2.123935     3
# 67          0  torch.Size([92, 17])           7      -3.770218 -1.295506     4
# 68          0  torch.Size([92, 17])           7      -9.437129 -2.792817     7
# 69          0  torch.Size([92, 17])           7     -11.370084 -1.932955     8
# 70          0  torch.Size([92, 17])           7     -13.351587 -0.580923    11
# 71          0  torch.Size([92, 17])           7     -13.207431  0.144156    12
# 72          0  torch.Size([92, 17])           7     -13.697816 -0.269975    15
# 73          0  torch.Size([92, 17])           7     -13.147427  0.550389    16
# 74          0  torch.Size([92, 17])           7     -13.147427  0.550389    16
# 75          0  torch.Size([92, 17])           7     -16.060619 -2.913193    17
# 76          0  torch.Size([92, 17])           7     -16.060619 -2.913193    17
# 77          0  torch.Size([92, 17])           8      -4.450225  0.525997     3
# 78          0  torch.Size([92, 17])           8      -4.990819 -0.540595     4
# 79          0  torch.Size([92, 17])           8      -9.565904 -1.866549     7
# 80          0  torch.Size([92, 17])           8     -10.301517 -0.735613     8
# 81          0  torch.Size([92, 17])           8     -15.561323 -2.921250    11
# 82          0  torch.Size([92, 17])           8     -16.188881 -0.627558    12
# 83          0  torch.Size([92, 17])           8     -21.503006 -2.076796    15
# 84          0  torch.Size([92, 17])           8     -24.535841 -3.032835    16
# 85          0  torch.Size([92, 17])           8     -29.892824 -2.515700    18
# 86          0  torch.Size([92, 17])           8     -34.830505 -4.937680    19
# 87          0  torch.Size([92, 17])           8     -34.830505 -4.937680    19
# 88          0  torch.Size([92, 17])           9       0.839989  0.837438     3
# 89          0  torch.Size([92, 17])           9       0.073975 -0.766014     4
# 90          0  torch.Size([92, 17])           9      -2.020076 -0.572046     7
# 91          0  torch.Size([92, 17])           9      -2.758760 -0.738684     8

# %%
# export
class FirstLastTfm(Transform):
    def __init__(self,gamma):
        store_attr()
        super().__init__()
        
        
    def encodes(self,o):
#         print('encoding')
        source,history=o['source'],o['history']
#         print(source,history,o)
        element=history[0]
        if history.bs()!=1:
            remainder=history[1:]
            reward=element['reward']
            for e in reversed(remainder['reward']):
                reward*=self.gamma
                reward+=e
            element['reward']=reward
            element['next_state']=history[-1]['next_state']
            element['done']=history[-1]['done']
            
#         print(source,element)
        return {'source':source,'history':element}
    
class FirstLast(LoopCallback):
    _methods=source_events
    _default='source'
                
    def __init__(self,gamma=0.99): store_attr()
    def before_episodes(self): self('initialize')    
    def initialize(self):
        if isinstance(self.source.return_fn,Pipeline):
            self.source.return_fn.add(FirstLastTfm(self.gamma))
        else:
            self.source.return_fn=Pipeline([self.source.return_fn,FirstLastTfm(self.gamma)])

# %%
source.show_loop()
# Out:
#  - after_create   : [GymLoop]
# Start Setup
#    - initialize     : [GymLoop]
# End Setup
#  - before_episodes: [GymLoop]
# Start Episodes
#    - reset          : [GymLoop]
#    - do_action      : []
#    - do_step        : [GymLoop]
#    - do_render      : []
#    - before_history : [GymLoop]
#    - history        : [GymLoop]
#    - after_history  : [GymLoop]
# End Episodes
#  - after_episodes : []

# %%
d=None 
source=Source(
    cbs=[GymLoop(env_name='CartPole-v1',steps_delta=1,steps_count=1),FirstLast]
)
for x,_ in zip(iter(source),range(50)): 
    if d is not None: d+=BD(x)
    else:             d=BD(x)
d.pandas(jupyter_nrows=40)
# Out:
#                   state           next_state   done  all_done  env_id  \
# 0   torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
# 1   torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
# 2   torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
# 3   torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
# 4   torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
# ..                  ...                  ...    ...       ...     ...
# 45  torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
# 46  torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
# 47  torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
# 48  torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
# 49  torch.Size([50, 4])  torch.Size([50, 4])  False     False       0
#
#     worker_id  action  episode_id  accum_rewards  reward  step
# 0           0     0.0           1            1.0     1.0     1
# 1           0     1.0           1            2.0     1.0     2
# 2           0     0.0           1            3.0     1.0     3
# 3           0     1.0           1            4.0     1.0     4
# 4           0     0.0           1            5.0     1.0     5
# ..        ...     ...         ...            ...     ...   ...
# 45          0     1.0           2            1.0     1.0     1
# 46          0     1.0           2            2.0     1.0     2
# 47          0     1.0           2            3.0     1.0     3
# 48          0     1.0           2            4.0     1.0     4
# 49          0     1.0           2            5.0     1.0     5
#
# [50 rows x 11 columns]

# %%
d=None 
source=Source(
    cbs=[GymLoop(env_name='CartPole-v1',steps_delta=1,steps_count=4),FirstLast]
)
for x,_ in zip(iter(source),range(50)): 
    if d is not None: d+=BD(x)
    else:             d=BD(x)
d.pandas(mu=True,jupyter_nrows=300)[['state_mu','next_state_mu','done']]
# Out:
#     state_mu  next_state_mu   done
# 0  -0.010672       0.033200  False
# 1  -0.035947       0.008566  False
# 2  -0.013006       0.033000  False
# 3   0.009899       0.009491  False
# 4   0.033200       0.035065  False
# 5   0.008566       0.061494  False
# 6   0.033000       0.040500  False
# 7   0.009491       0.020360  False
# 8   0.035065       0.000667  False
# 9   0.061494       0.029489  False
# 10  0.040500       0.058880  False
# 11  0.020360       0.040847  False
# 12  0.000667       0.071718  False
# 13  0.029489       0.103663  False
# 14  0.058880       0.089102  False
# 15  0.040847       0.075848  False
# 16  0.071718       0.110917  False
# 17  0.103663       0.147253  False
# 18  0.089102       0.138438  False
# 19  0.075848       0.131374  False
# 20  0.110917       0.171424   True
# 21  0.147253       0.171424   True
# 22  0.138438       0.171424   True
# 23  0.131374       0.171424   True
# 24 -0.003834       0.005744  False
# 25 -0.024938      -0.016880  False
# 26 -0.046478       0.008841  False
# 27 -0.020228      -0.014032  False
# 28  0.005744      -0.037283  False
# 29 -0.016880      -0.061349  False
# 30  0.008841      -0.037892  False
# 31 -0.014032      -0.063930  False
# 32 -0.037283      -0.091231  False
# 33 -0.061349      -0.071561  False
# 34 -0.037892      -0.053214  False
# 35 -0.063930      -0.084133  False
# 36 -0.091231      -0.068221  False
# 37 -0.071561      -0.053396  False
# 38 -0.053214      -0.086987  False
# 39 -0.084133      -0.121684  False
# 40 -0.068221      -0.110584  False
# 41 -0.053396      -0.147813  False
# 42 -0.086987      -0.186666  False
# 43 -0.121684      -0.227532   True
# 44 -0.110584      -0.227532   True
# 45 -0.147813      -0.227532   True
# 46 -0.186666      -0.227532   True
# 47  0.015739       0.018920  False
# 48 -0.007630      -0.004442  False
# 49  0.017278      -0.028275  False

# %%
d=None 
source=Source(
    cbs=[GymLoop(env_name='HumanoidPyBulletEnv-v0',steps_delta=3),FirstLast]
)
for x,_ in zip(iter(source),range(50)): 
    if d is not None: d+=BD(x)
    else:             d=BD(x)
d.pandas(jupyter_nrows=300)
# Out:
# /home/fastrl_user/.local/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WalkerBase::__init__
# WalkerBase::__init__
# WalkerBase::__init__
#                    state            next_state   done  all_done  env_id  \
# 0   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 1   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 2   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 3   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 4   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 5   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 6   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 7   torch.Size([50, 44])  torch.Size([50, 44])   True      True       0
# 8   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 9   torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 10  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 11  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 12  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 13  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 14  torch.Size([50, 44])  torch.Size([50, 44])   True      True       0
# 15  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 16  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 17  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 18  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 19  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 20  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 21  torch.Size([50, 44])  torch.Size([50, 44])   True      True       0
# 22  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 23  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 24  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 25  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 26  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 27  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 28  torch.Size([50, 44])  torch.Size([50, 44])   True      True       0
# 29  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 30  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 31  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 32  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 33  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 34  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 35  torch.Size([50, 44])  torch.Size([50, 44])   True      True       0
# 36  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 37  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 38  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 39  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 40  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 41  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 42  torch.Size([50, 44])  torch.Size([50, 44])   True      True       0
# 43  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 44  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 45  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 46  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 47  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 48  torch.Size([50, 44])  torch.Size([50, 44])  False     False       0
# 49  torch.Size([50, 44])  torch.Size([50, 44])   True      True       0
#
#     worker_id                action  episode_id  accum_rewards    reward  step
# 0           0  torch.Size([50, 17])           1      -1.913849  0.821911     3
# 1           0  torch.Size([50, 17])           1      -5.483688 -0.966598     6
# 2           0  torch.Size([50, 17])           1     -12.645121 -1.738530     9
# 3           0  torch.Size([50, 17])           1     -18.006485 -0.390826    12
# 4           0  torch.Size([50, 17])           1     -19.800539 -0.535224    15
# 5           0  torch.Size([50, 17])           1     -26.467159 -2.372724    18
# 6           0  torch.Size([50, 17])           1     -28.829042 -0.902850    21
# 7           0  torch.Size([50, 17])           1     -32.096977 -3.158662    23
# 8           0  torch.Size([50, 17])           2      -3.838071 -2.110845     3
# 9           0  torch.Size([50, 17])           2     -14.129688 -2.812963     6
# 10          0  torch.Size([50, 17])           2     -18.805380 -1.727969     9
# 11          0  torch.Size([50, 17])           2     -24.945814 -1.658930    12
# 12          0  torch.Size([50, 17])           2     -32.713753 -1.363996    15
# 13          0  torch.Size([50, 17])           2     -40.530331 -4.479223    18
# 14          0  torch.Size([50, 17])           2     -45.993401 -5.463069    19
# 15          0  torch.Size([50, 17])           3      -0.040341 -0.157032     3
# 16          0  torch.Size([50, 17])           3      -6.918172 -4.830307     6
# 17          0  torch.Size([50, 17])           3     -11.014926 -0.681399     9
# 18          0  torch.Size([50, 17])           3     -14.416595 -1.228313    12
# 19          0  torch.Size([50, 17])           3     -21.389008 -1.209874    15
# 20          0  torch.Size([50, 17])           3     -23.310417 -0.299338    18
# 21          0  torch.Size([50, 17])           3     -27.522224 -4.211806    19
# 22          0  torch.Size([50, 17])           4      -4.262700 -3.457991     3
# 23          0  torch.Size([50, 17])           4      -7.110518 -0.420313     6
# 24          0  torch.Size([50, 17])           4      -8.916959 -0.576311     9
# 25          0  torch.Size([50, 17])           4     -10.342894 -0.377089    12
# 26          0  torch.Size([50, 17])           4     -14.479233 -0.652423    15
# 27          0  torch.Size([50, 17])           4     -17.075680 -1.814829    18
# 28          0  torch.Size([50, 17])           4     -22.492178 -5.416498    19
# 29          0  torch.Size([50, 17])           5      -1.667941 -1.192647     3
# 30          0  torch.Size([50, 17])           5      -6.681935 -2.282432     6
# 31          0  torch.Size([50, 17])           5      -9.391359 -1.367723     9
# 32          0  torch.Size([50, 17])           5     -13.256204 -1.135298    12
# 33          0  torch.Size([50, 17])           5     -20.854996 -2.975049    15
# 34          0  torch.Size([50, 17])           5     -25.395943 -0.909044    18
# 35          0  torch.Size([50, 17])           5     -34.032753 -8.636808    19
# 36          0  torch.Size([50, 17])           6      -5.312354 -2.523067     3
# 37          0  torch.Size([50, 17])           6      -9.258152 -2.242941     6
# 38          0  torch.Size([50, 17])           6     -14.404008 -2.620623     9
# 39          0  torch.Size([50, 17])           6     -16.620630 -0.928190    12
# 40          0  torch.Size([50, 17])           6     -23.122997 -2.022895    15
# 41          0  torch.Size([50, 17])           6     -25.567642 -0.097385    18
# 42          0  torch.Size([50, 17])           6     -29.150036 -3.582394    19
# 43          0  torch.Size([50, 17])           7      -2.570872 -0.173808     3
# 44          0  torch.Size([50, 17])           7      -6.701797 -1.293379     6
# 45          0  torch.Size([50, 17])           7     -12.244434 -1.105217     9
# 46          0  torch.Size([50, 17])           7     -20.777300 -2.192820    12
# 47          0  torch.Size([50, 17])           7     -24.374006 -0.567158    15
# 48          0  torch.Size([50, 17])           7     -27.602919  0.004013    18
# 49          0  torch.Size([50, 17])           7     -34.394882 -4.629518    20

# %% [markdown]
# ### Metrics

# %%
# export
class Reward(Metric):
    order=30
    reward=None
    rolling_reward_n=100
    keep_rewards=False

    def reset(self):
        if self.reward is None: self.reward=deque(maxlen=self.rolling_reward_n)
            
    def accumulate(self,learn):
        xb=learn.xb[0]
        if xb['all_done'].sum()>0:
            final_rewards=to_detach(xb['accum_rewards'][xb['all_done']])
            for i in final_rewards.reshape(-1,).numpy().tolist(): self.reward.append(i)
                
    @property
    def value(self): return np.average(self.reward) if len(self.reward)>0 else 0

# %%
# export
class NEpisodes(Metric):
    order=30
    n_episodes=None

    def reset(self):
        if self.n_episodes is None: self.n_episodes=0
            
    def accumulate(self,learn):
        xb=learn.xb[0]
        if xb['all_done'].sum()>0:
            new_episodes=torch.unique(to_detach(xb['episode_id'][xb['all_done']]))
            self.n_episodes+=len(new_episodes)
                
                
    @property
    def value(self): return self.n_episodes

# %%
from torch.nn import Linear

class FakeModel(Module):
    def __init__(self):
        self.fc=Linear(5,5)
        
    def forward(self,x):
#         print(x)
        return x

# %%
source=Source(cbs=[GymLoop(env_name='CartPole-v1'),FirstLast])
block=SourceDataBlock()
dls=block.dataloaders([source],n=1000,bs=64,num_workers=0,verbose=False)
learn=Learner(dls,FakeModel(),metrics=[Reward,NEpisodes],loss_func=lambda o: 0.5)
learn.fit(4)
# Out:
# Could not do one pass in your dataloader, there is something wrong in it
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>train_reward</th>
#       <th>train_n_episodes</th>
#       <th>valid_loss</th>
#       <th>valid_reward</th>
#       <th>valid_n_episodes</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.000000</td>
#       <td>21.108696</td>
#       <td>46</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>21.380435</td>
#       <td>92</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>22.390000</td>
#       <td>135</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>22.100000</td>
#       <td>180</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>
# argv[0]=
# argv[0]=
# argv[0]=
# argv[0]=

# %% [markdown]
# ## Export

# %%
# hide
from fastcore.imports import in_colab

# Since colab still requires tornado<6, we don't want to import nbdev if we don't have to
if not in_colab():
    from nbdev.export import *
    from nbdev.export2html import *
    from nbdev.cli import make_readme
    make_readme()
    notebook2script()
    notebook2html()
# Out:
# converting /home/fastrl_user/fastrl/nbs/index.ipynb to README.md
# Converted 00_core.ipynb.
# Converted 00_nbdev_extension.ipynb.
# Converted 03_callback.core.ipynb.
# Converted 04_agent.ipynb.
# Converted 05_data.test_async.ipynb.
# Converted 05a_data.block.ipynb.
# Converted 05b_data.block_simple.ipynb.
# Converted 05c_data.gym.ipynb.
# Converted 10a_agents.dqn.core.ipynb.
# Converted 10b_agents.dqn.targets.ipynb.
# Converted 10c_agents.dqn.double.ipynb.
# Converted 10d_agents.dqn.dueling.ipynb.
# Converted 10e_agents.dqn.categorical.ipynb.
# Converted 11a_agents.policy_gradient.ppo.ipynb.
# Converted 20_test_utils.ipynb.
# Converted index.ipynb.
# Converted nbdev_template.ipynb.
# No notebooks were modified
