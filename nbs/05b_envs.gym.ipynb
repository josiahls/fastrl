# %%
#|hide
#|eval: false
! [ -e /content ] && pip install -Uqq fastrl['dev'] pyvirtualdisplay && \
                     apt-get install -y xvfb python-opengl > /dev/null 2>&1 
# NOTE: IF YOU SEE VERSION ERRORS, IT IS SAFE TO IGNORE THEM. COLAB IS BEHIND IN SOME OF THE PACKAGE VERSIONS

# %%
#|hide
from fastcore.imports import in_colab
# Since colab still requires tornado<6, we don't want to import nbdev if we don't have to
if not in_colab():
    from nbdev.showdoc import *
    from nbdev.imports import *
    if not os.environ.get("IN_TEST", None):
        assert IN_NOTEBOOK
        assert not IN_COLAB
        assert IN_IPYTHON
else:
    # Virutual display is needed for colab
    from pyvirtualdisplay import Display
    display = Display(visible=0, size=(400, 300))
    display.start()

# %%
#|default_exp envs.gym

# %%
#|export
# Python native modules
import os
import warnings
# Third party libs
from fastcore.all import *
import torchdata.datapipes as dp
import gym
from fastai.torch_basics import *
from fastai.torch_core import *
from torch.utils.data.dataloader_experimental import DataLoader2
from torchdata.dataloader2.graph import find_dps,traverse
# Local modules
from fastrl.core import *
from fastrl.pipes.core import *
from fastrl.pipes.iter.nskip import *
from fastrl.pipes.iter.nstep import *
from fastrl.pipes.iter.firstlast import *
from fastrl.fastai.data.block import *

# %% [markdown]
# # Envs Gym
# > Fastrl API for working with OpenAI Gyms

# %% [markdown]
# ### Pipes

# %%
#|export
class GymTypeTransform(Transform):
    "Creates an gym.env"
    def encodes(self,o): return gym.make(o,new_step_api=True)

# %%
#|export
class GymStepper(dp.iter.IterDataPipe):
    def __init__(self,
        source_datapipe:Union[Iterable,dp.iter.IterDataPipe], # Calling `next()` should produce a `gym.Env`
        agent=None, # Optional `Agent` that accepts a `SimpleStep` to produce a list of actions.
        seed:int=None, # Optional seed to set the env to and also random action sames if `agent==None`
        synchronized_reset:bool=False, # Some `gym.Envs` require reset to be terminated on *all* envs before proceeding to step.
        include_images:bool=False,
    ):
        self.source_datapipe = source_datapipe
        self.agent = agent
        self.seed = seed
        self.include_images = include_images
        self.synchronized_reset = synchronized_reset
        self._env_ids = {}
        
    def env_reset(self,
      env:gym.Env, # The env to rest along with its numeric object id
      env_id:int # Resets env in `self._env_ids[env_id]`
    ) -> SimpleStep:
        state = env.reset(seed=self.seed)
        env.action_space.seed(seed=self.seed)
        episode_n = self._env_ids[env_id].episode_n+1 if env_id in self._env_ids else tensor(1)

        step = (self.no_agent_create_step if self.agent is None else self.agent.create_step)(
            state=tensor(state),
            next_state=tensor(state),
            terminated=tensor(False),
            truncated=tensor(False),
            reward=tensor(0),
            total_reward=tensor(0.),
            env_id=tensor(env_id),
            proc_id=tensor(os.getpid()),
            step_n=tensor(0),
            episode_n=episode_n,
            image=env.render(mode='rgb_array') if self.include_images else torch.FloatTensor([0])
        )
        self._env_ids[env_id] = step
        return step
    
    def no_agent_create_step(self,**kwargs): return SimpleStep(**kwargs)

    def __iter__(self) -> SimpleStep:
        for env in self.source_datapipe:
            assert issubclass(env.__class__,gym.Env),f'Expected subclass of gym.Env, but got {env.__class__}'    
            env_id = id(env)
            
            if env_id not in self._env_ids or self._env_ids[env_id].terminated:
                if self.synchronized_reset:
                    if env_id in self._env_ids \
                       and not self._env_ids[env_id].terminated \
                       and self._resetting_all:
                        # If this env has already been reset, and we are currently in the 
                        # self._resetting_all phase, then skip this so we can reset all remaining envs
                        continue
                    elif env_id not in self._env_ids \
                       or all([self._env_ids[s].terminated for s in self._env_ids])\
                       or self._resetting_all:
                        # If the id is not in the _env_ids, we can assume this is a fresh start.
                        # OR 
                        # If all the envs are terminated, then we can start doing a reset operation.
                        # OR
                        # If we are currently resetting all the envs anyways
                        # This means we want to reset ALL the envs before doing any steps.
                        self.env_reset(env,env_id)
                        # Move to the next env, eventually we will reset all the envs in sync.
                        # then we will be able to start calling `step` for each of them.
                        # _resetting_all is True when there are envs still "terminated".
                        self._resetting_all = any([self._env_ids[s].terminated for s in self._env_ids])
                        continue 
                    elif self._env_ids[env_id].terminated:
                        continue
                    else:
                        raise ValueError('This else should never happen.')
                else:
                    step = self.env_reset(env,env_id)
            else:
                step = self._env_ids[env_id]

            action = None
            for action in (self.agent([step]) if self.agent is not None else [env.action_space.sample()]):
                next_state,reward,terminated,truncated,_ = env.step(
                    self.agent.augment_actions(action) if self.agent is not None else action
                )

                step = (self.no_agent_create_step if self.agent is None else self.agent.create_step)(
                    state=tensor(step.next_state),
                    next_state=tensor(next_state),
                    action=tensor(action).float(),
                    terminated=tensor(terminated),
                    truncated=tensor(truncated),
                    reward=tensor(reward),
                    total_reward=step.total_reward+reward,
                    env_id=tensor(env_id),
                    proc_id=tensor(os.getpid()),
                    step_n=step.step_n+1,
                    episode_n=step.episode_n,
                    image=env.render(mode='rgb_array') if self.include_images else torch.FloatTensor([0])
                )
                self._env_ids[env_id] = step
                yield step
                if terminated: break
            if action is None: 
                raise Exception('The agent produced no actions. This should never occur.')
                
add_docs(
    GymStepper,
    """Accepts a `source_datapipe` or iterable whose `next()` produces a single `gym.Env`.
       Tracks multiple envs using `id(env)`.""",
    env_reset="Resets a env given the env_id.",
    no_agent_create_step="If there is no agent for creating the step output, then `GymStepper` will create its own"
)

# %%
#|hide
# Used here to avoid UserWarnings related to gym complaining about bounding box / action space format.
# There must be a bug in the CartPole-v1 env that is causing this to show. Also couldnt figure out the 
# regex, so instead we filter on the lineno, which is line 98.
warnings.filterwarnings("ignore",category=UserWarning,lineno=98)

# %% [markdown]
# ## Iteration Examples

# %%
#|eval: False
import pandas as pd
from fastrl.agents.core import * 

class ConstantRunner(dp.iter.IterDataPipe):
    def __init__(self,source_datapipe,constant=1,array_nestings=0): 
        self.source_datapipe = source_datapipe
        self.agent_base = find_dp(traverse(self.source_datapipe),AgentBase)
        self.constant = constant
        self.array_nestings = array_nestings
    
    def __iter__(self):
        for o in self.source_datapipe: 
            try: 
                if self.array_nestings==0: yield self.constant
                else:
                    yield [self.constant]*self.array_nestings
            except Exception:
                print('Failed on ',o)
                raise

agent = AgentBase(None,[])
agent = ConstantRunner(agent)
agent = AgentHead(agent)

pipe = dp.map.Mapper(['CartPole-v1']*3)
pipe = TypeTransformLoop(pipe,[GymTypeTransform])
pipe = dp.iter.MapToIterConverter(pipe)
pipe = dp.iter.InMemoryCacheHolder(pipe)
pipe = pipe.cycle()
pipe = GymStepper(pipe,agent=agent,seed=0)

pd.DataFrame([step for step,_ in zip(*(pipe,range(10)))])[['state','next_state','action','terminated']]
# Out:
#                                                                  state  \
# 0  [tensor(0.0137), tensor(-0.0230), tensor(-0.0459), tensor(-0.0483)]
# 1  [tensor(0.0137), tensor(-0.0230), tensor(-0.0459), tensor(-0.0483)]
# 2  [tensor(0.0137), tensor(-0.0230), tensor(-0.0459), tensor(-0.0483)]
# 3   [tensor(0.0132), tensor(0.1727), tensor(-0.0469), tensor(-0.3552)]
# 4   [tensor(0.0132), tensor(0.1727), tensor(-0.0469), tensor(-0.3552)]
# 5   [tensor(0.0132), tensor(0.1727), tensor(-0.0469), tensor(-0.3552)]
# 6   [tensor(0.0167), tensor(0.3685), tensor(-0.0540), tensor(-0.6622)]
# 7   [tensor(0.0167), tensor(0.3685), tensor(-0.0540), tensor(-0.6622)]
# 8   [tensor(0.0167), tensor(0.3685), tensor(-0.0540), tensor(-0.6622)]
# 9   [tensor(0.0241), tensor(0.5643), tensor(-0.0672), tensor(-0.9714)]
#
#                                                            next_state  \
# 0  [tensor(0.0132), tensor(0.1727), tensor(-0.0469), tensor(-0.3552)]
# 1  [tensor(0.0132), tensor(0.1727), tensor(-0.0469), tensor(-0.3552)]
# 2  [tensor(0.0132), tensor(0.1727), tensor(-0.0469), tensor(-0.3552)]
# 3  [tensor(0.0167), tensor(0.3685), tensor(-0.0540), tensor(-0.6622)]
# 4  [tensor(0.0167), tensor(0.3685), tensor(-0.0540), tensor(-0.6622)]
# 5  [tensor(0.0167), tensor(0.3685), tensor(-0.0540), tensor(-0.6622)]
# 6  [tensor(0.0241), tensor(0.5643), tensor(-0.0672), tensor(-0.9714)]
# 7  [tensor(0.0241), tensor(0.5643), tensor(-0.0672), tensor(-0.9714)]
# 8  [tensor(0.0241), tensor(0.5643), tensor(-0.0672), tensor(-0.9714)]
# 9  [tensor(0.0353), tensor(0.7603), tensor(-0.0866), tensor(-1.2844)]
#
#        action     terminated
# 0  tensor(1.)  tensor(False)
# 1  tensor(1.)  tensor(False)
# 2  tensor(1.)  tensor(False)
# 3  tensor(1.)  tensor(False)
# 4  tensor(1.)  tensor(False)
# 5  tensor(1.)  tensor(False)
# 6  tensor(1.)  tensor(False)
# 7  tensor(1.)  tensor(False)
# 8  tensor(1.)  tensor(False)
# 9  tensor(1.)  tensor(False)

# %%
pipe = dp.map.Mapper(['CartPole-v1']*3)
pipe = TypeTransformLoop(pipe,[GymTypeTransform])
pipe = dp.iter.MapToIterConverter(pipe)
pipe = dp.iter.InMemoryCacheHolder(pipe)
pipe = pipe.cycle()
pipe = GymStepper(pipe,seed=0)

pd.DataFrame([step for step,_ in zip(*(pipe,range(10)))])[['state','next_state','action','terminated']]
# Out:
#                                                                  state  \
# 0  [tensor(0.0137), tensor(-0.0230), tensor(-0.0459), tensor(-0.0483)]
# 1  [tensor(0.0137), tensor(-0.0230), tensor(-0.0459), tensor(-0.0483)]
# 2  [tensor(0.0137), tensor(-0.0230), tensor(-0.0459), tensor(-0.0483)]
# 3   [tensor(0.0132), tensor(0.1727), tensor(-0.0469), tensor(-0.3552)]
# 4   [tensor(0.0132), tensor(0.1727), tensor(-0.0469), tensor(-0.3552)]
# 5   [tensor(0.0132), tensor(0.1727), tensor(-0.0469), tensor(-0.3552)]
# 6   [tensor(0.0167), tensor(0.3685), tensor(-0.0540), tensor(-0.6622)]
# 7   [tensor(0.0167), tensor(0.3685), tensor(-0.0540), tensor(-0.6622)]
# 8   [tensor(0.0167), tensor(0.3685), tensor(-0.0540), tensor(-0.6622)]
# 9   [tensor(0.0241), tensor(0.5643), tensor(-0.0672), tensor(-0.9714)]
#
#                                                            next_state  \
# 0  [tensor(0.0132), tensor(0.1727), tensor(-0.0469), tensor(-0.3552)]
# 1  [tensor(0.0132), tensor(0.1727), tensor(-0.0469), tensor(-0.3552)]
# 2  [tensor(0.0132), tensor(0.1727), tensor(-0.0469), tensor(-0.3552)]
# 3  [tensor(0.0167), tensor(0.3685), tensor(-0.0540), tensor(-0.6622)]
# 4  [tensor(0.0167), tensor(0.3685), tensor(-0.0540), tensor(-0.6622)]
# 5  [tensor(0.0167), tensor(0.3685), tensor(-0.0540), tensor(-0.6622)]
# 6  [tensor(0.0241), tensor(0.5643), tensor(-0.0672), tensor(-0.9714)]
# 7  [tensor(0.0241), tensor(0.5643), tensor(-0.0672), tensor(-0.9714)]
# 8  [tensor(0.0241), tensor(0.5643), tensor(-0.0672), tensor(-0.9714)]
# 9  [tensor(0.0353), tensor(0.3702), tensor(-0.0866), tensor(-0.7006)]
#
#        action     terminated
# 0  tensor(1.)  tensor(False)
# 1  tensor(1.)  tensor(False)
# 2  tensor(1.)  tensor(False)
# 3  tensor(1.)  tensor(False)
# 4  tensor(1.)  tensor(False)
# 5  tensor(1.)  tensor(False)
# 6  tensor(1.)  tensor(False)
# 7  tensor(1.)  tensor(False)
# 8  tensor(1.)  tensor(False)
# 9  tensor(0.)  tensor(False)

# %%
from torch.utils.data.dataloader_experimental import DataLoader2

def seed_worker(worker_id): torch.manual_seed(0)

dl = DataLoader2(pipe,num_workers=2,worker_init_fn=seed_worker)

pd.DataFrame([step for step,_ in zip(*(dl,range(10)))])[['state','next_state','action','terminated']]
# Out:
#                                                                   state  \
# 0  [[tensor(0.0353), tensor(0.3702), tensor(-0.0866), tensor(-0.7006)]]
# 1  [[tensor(0.0353), tensor(0.3702), tensor(-0.0866), tensor(-0.7006)]]
# 2  [[tensor(0.0353), tensor(0.3702), tensor(-0.0866), tensor(-0.7006)]]
# 3  [[tensor(0.0353), tensor(0.3702), tensor(-0.0866), tensor(-0.7006)]]
# 4  [[tensor(0.0241), tensor(0.5643), tensor(-0.0672), tensor(-0.9714)]]
# 5  [[tensor(0.0241), tensor(0.5643), tensor(-0.0672), tensor(-0.9714)]]
# 6  [[tensor(0.0427), tensor(0.1763), tensor(-0.1007), tensor(-0.4364)]]
# 7  [[tensor(0.0427), tensor(0.1763), tensor(-0.1007), tensor(-0.4364)]]
# 8  [[tensor(0.0427), tensor(0.1763), tensor(-0.1007), tensor(-0.4364)]]
# 9  [[tensor(0.0427), tensor(0.1763), tensor(-0.1007), tensor(-0.4364)]]
#
#                                                               next_state  \
# 0   [[tensor(0.0427), tensor(0.1763), tensor(-0.1007), tensor(-0.4364)]]
# 1   [[tensor(0.0427), tensor(0.1763), tensor(-0.1007), tensor(-0.4364)]]
# 2   [[tensor(0.0427), tensor(0.1763), tensor(-0.1007), tensor(-0.4364)]]
# 3   [[tensor(0.0427), tensor(0.1763), tensor(-0.1007), tensor(-0.4364)]]
# 4   [[tensor(0.0353), tensor(0.3702), tensor(-0.0866), tensor(-0.7006)]]
# 5   [[tensor(0.0353), tensor(0.3702), tensor(-0.0866), tensor(-0.7006)]]
# 6  [[tensor(0.0463), tensor(-0.0172), tensor(-0.1094), tensor(-0.1771)]]
# 7  [[tensor(0.0463), tensor(-0.0172), tensor(-0.1094), tensor(-0.1771)]]
# 8  [[tensor(0.0463), tensor(-0.0172), tensor(-0.1094), tensor(-0.1771)]]
# 9  [[tensor(0.0463), tensor(-0.0172), tensor(-0.1094), tensor(-0.1771)]]
#
#          action       terminated
# 0  [tensor(0.)]  [tensor(False)]
# 1  [tensor(0.)]  [tensor(False)]
# 2  [tensor(0.)]  [tensor(False)]
# 3  [tensor(0.)]  [tensor(False)]
# 4  [tensor(0.)]  [tensor(False)]
# 5  [tensor(0.)]  [tensor(False)]
# 6  [tensor(0.)]  [tensor(False)]
# 7  [tensor(0.)]  [tensor(False)]
# 8  [tensor(0.)]  [tensor(False)]
# 9  [tensor(0.)]  [tensor(False)]

# %%
pipe = dp.map.Mapper(['CartPole-v1']*3)
pipe = TypeTransformLoop(pipe,[GymTypeTransform])
pipe = dp.iter.MapToIterConverter(pipe)
pipe = dp.iter.InMemoryCacheHolder(pipe)
pipe = pipe.cycle()
pipe = GymStepper(pipe,synchronized_reset=True)

pd.DataFrame([step for step,_ in zip(*(dl,range(10)))])[['state','next_state','action','terminated']]
# Out:
#                                                                   state  \
# 0  [[tensor(0.0353), tensor(0.3702), tensor(-0.0866), tensor(-0.7006)]]
# 1  [[tensor(0.0353), tensor(0.3702), tensor(-0.0866), tensor(-0.7006)]]
# 2  [[tensor(0.0353), tensor(0.3702), tensor(-0.0866), tensor(-0.7006)]]
# 3  [[tensor(0.0353), tensor(0.3702), tensor(-0.0866), tensor(-0.7006)]]
# 4  [[tensor(0.0241), tensor(0.5643), tensor(-0.0672), tensor(-0.9714)]]
# 5  [[tensor(0.0241), tensor(0.5643), tensor(-0.0672), tensor(-0.9714)]]
# 6  [[tensor(0.0427), tensor(0.1763), tensor(-0.1007), tensor(-0.4364)]]
# 7  [[tensor(0.0427), tensor(0.1763), tensor(-0.1007), tensor(-0.4364)]]
# 8  [[tensor(0.0427), tensor(0.1763), tensor(-0.1007), tensor(-0.4364)]]
# 9  [[tensor(0.0427), tensor(0.1763), tensor(-0.1007), tensor(-0.4364)]]
#
#                                                               next_state  \
# 0   [[tensor(0.0427), tensor(0.1763), tensor(-0.1007), tensor(-0.4364)]]
# 1   [[tensor(0.0427), tensor(0.1763), tensor(-0.1007), tensor(-0.4364)]]
# 2   [[tensor(0.0427), tensor(0.1763), tensor(-0.1007), tensor(-0.4364)]]
# 3   [[tensor(0.0427), tensor(0.1763), tensor(-0.1007), tensor(-0.4364)]]
# 4   [[tensor(0.0353), tensor(0.3702), tensor(-0.0866), tensor(-0.7006)]]
# 5   [[tensor(0.0353), tensor(0.3702), tensor(-0.0866), tensor(-0.7006)]]
# 6  [[tensor(0.0463), tensor(-0.0172), tensor(-0.1094), tensor(-0.1771)]]
# 7  [[tensor(0.0463), tensor(-0.0172), tensor(-0.1094), tensor(-0.1771)]]
# 8  [[tensor(0.0463), tensor(-0.0172), tensor(-0.1094), tensor(-0.1771)]]
# 9  [[tensor(0.0463), tensor(-0.0172), tensor(-0.1094), tensor(-0.1771)]]
#
#          action       terminated
# 0  [tensor(0.)]  [tensor(False)]
# 1  [tensor(0.)]  [tensor(False)]
# 2  [tensor(0.)]  [tensor(False)]
# 3  [tensor(0.)]  [tensor(False)]
# 4  [tensor(0.)]  [tensor(False)]
# 5  [tensor(0.)]  [tensor(False)]
# 6  [tensor(0.)]  [tensor(False)]
# 7  [tensor(0.)]  [tensor(False)]
# 8  [tensor(0.)]  [tensor(False)]
# 9  [tensor(0.)]  [tensor(False)]

# %% [markdown]
# ## Tests

# %% [markdown]
# We create 3 envs and put a max iteration count at 180. Each env will run for 18 steps before ending, which means
# we expect there to be 10 total episodes.

# %%
import pandas as pd

envs = ['CartPole-v1']*3
n_episodes = 3

pipe = dp.map.Mapper(envs)
pipe = TypeTransformLoop(pipe,[GymTypeTransform])
pipe = dp.iter.MapToIterConverter(pipe)
pipe = dp.iter.InMemoryCacheHolder(pipe)
# We want to cycle through the envs enough times that their epsiode sum to 9, 3 episodes each
pipe = pipe.cycle(count=(18*len(envs))) 
pipe = GymStepper(pipe,seed=0)

# %% [markdown]
# All the of the environments should reach max 18 steps given a seed of 0...\
# The total number of iterations should be `( 18 * n_envs) * n_episodes_per_env = 162`...

# %%
steps = list(pipe)
gsteps = groupby(steps,lambda o:int(o.step_n))
test_len(gsteps.keys(),18)
pd.DataFrame([step for step in steps])[['state','terminated','env_id','episode_n','step_n']][::10]
# Out:
#                                                                    state  \
# 0    [tensor(0.0137), tensor(-0.0230), tensor(-0.0459), tensor(-0.0483)]
# 10    [tensor(0.0241), tensor(0.5643), tensor(-0.0672), tensor(-0.9714)]
# 20   [tensor(0.0463), tensor(-0.0172), tensor(-0.1094), tensor(-0.1771)]
# 30    [tensor(0.0217), tensor(-0.4009), tensor(-0.0929), tensor(0.2661)]
# 40    [tensor(0.0094), tensor(0.1879), tensor(-0.0961), tensor(-0.6926)]
# 50    [tensor(0.0325), tensor(0.7771), tensor(-0.1570), tensor(-1.6694)]
# 60    [tensor(0.0167), tensor(0.3685), tensor(-0.0540), tensor(-0.6622)]
# 70    [tensor(0.0427), tensor(0.1763), tensor(-0.1007), tensor(-0.4364)]
# 80    [tensor(0.0417), tensor(-0.4040), tensor(-0.1113), tensor(0.3342)]
# 90   [tensor(0.0096), tensor(-0.0083), tensor(-0.0886), tensor(-0.3733)]
# 100   [tensor(0.0209), tensor(0.5806), tensor(-0.1302), tensor(-1.3390)]
# 110  [tensor(0.0137), tensor(-0.0230), tensor(-0.0459), tensor(-0.0483)]
# 120   [tensor(0.0353), tensor(0.3702), tensor(-0.0866), tensor(-0.7006)]
# 130   [tensor(0.0459), tensor(-0.2106), tensor(-0.1129), tensor(0.0792)]
# 140   [tensor(0.0217), tensor(-0.4009), tensor(-0.0929), tensor(0.2661)]
# 150   [tensor(0.0132), tensor(0.3842), tensor(-0.1099), tensor(-1.0139)]
# 160   [tensor(0.0480), tensor(0.9737), tensor(-0.1904), tensor(-2.0066)]
#
#         terminated                   env_id  episode_n      step_n
# 0    tensor(False)  tensor(140041770169936)  tensor(1)   tensor(1)
# 10   tensor(False)  tensor(140041770171024)  tensor(1)   tensor(4)
# 20   tensor(False)  tensor(140041770171152)  tensor(1)   tensor(7)
# 30   tensor(False)  tensor(140041770169936)  tensor(1)  tensor(11)
# 40   tensor(False)  tensor(140041770171024)  tensor(1)  tensor(14)
# 50   tensor(False)  tensor(140041770171152)  tensor(1)  tensor(17)
# 60   tensor(False)  tensor(140041770169936)  tensor(2)   tensor(3)
# 70   tensor(False)  tensor(140041770171024)  tensor(2)   tensor(6)
# 80   tensor(False)  tensor(140041770171152)  tensor(2)   tensor(9)
# 90   tensor(False)  tensor(140041770169936)  tensor(2)  tensor(13)
# 100  tensor(False)  tensor(140041770171024)  tensor(2)  tensor(16)
# 110  tensor(False)  tensor(140041770171152)  tensor(3)   tensor(1)
# 120  tensor(False)  tensor(140041770169936)  tensor(3)   tensor(5)
# 130  tensor(False)  tensor(140041770171024)  tensor(3)   tensor(8)
# 140  tensor(False)  tensor(140041770171152)  tensor(3)  tensor(11)
# 150  tensor(False)  tensor(140041770169936)  tensor(3)  tensor(15)
# 160   tensor(True)  tensor(140041770171024)  tensor(3)  tensor(18)

# %% [markdown]
# All of the step groups should be the same length...

# %%
group_sz = None
for name,group in gsteps.items():
    if group_sz is None: group_sz = len(group)
    else:                assert len(group)==group_sz,f' Got lengths {len(group)} and {group_sz} for {name}.\n\n{group}'

# %% [markdown]
# Each step group's state and next_states should match across envs...

# %%
group_sz = None
for name,group in gsteps.items():
    e1 = group[0]
    for other in group[1:]: test_eq(e1.state,other.state)
    for other in group[1:]: test_eq(e1.next_state,other.next_state)

# %% [markdown]
# Each step group value should not show up/be duplicated in any other step groups...

# %%
group_sz = None
for name,group in gsteps.items():
    e1 = group[0]
    for other_name,other_group in gsteps.items():
        if other_name==name: continue
        for other in other_group[1:]: test_ne(e1.state,other.state)
        for other in other_group[1:]: test_ne(e1.next_state,other.next_state)

# %% [markdown]
# Given 3 envs, single steps, epsiodes of 18 steps in len, 3 episodes each, run for 162 iterations, we should
# expect there to be 9 dones.

# %%
test_eq(sum([o.terminated for o in steps]),tensor([9]))

# %% [markdown]
# The max episode numbers for each env should sum to 9 where for each env, it should reach and finish 3 episodes...

# %%
gsteps = groupby(steps,lambda o:int(o.env_id))
test_len(gsteps.keys(),3)
env1,env2,env3 = L(gsteps.values()).map(L).map(Self.map(Self.episode_n()).map(int))
test_eq(max(env1)+max(env2)+max(env3),9)

# %% [markdown]
# ### Test the `synchronized_reset` param...
# > In this case, we will have iterate through the 3 envs without producing a step on warmup.

# %%
import pandas as pd

envs = ['CartPole-v1']*3
n_episodes = 3

pipe = dp.map.Mapper(envs)
pipe = TypeTransformLoop(pipe,[GymTypeTransform])
pipe = dp.iter.MapToIterConverter(pipe)
pipe = dp.iter.InMemoryCacheHolder(pipe)
# We want to cycle through the envs enough times that their epsiode sum to 9, 3 episodes each
# We add an additional +3 cycles since `synchronized_reset` cycles through the envs additional times
# to make sure they are all reset prior to stepping
pipe = pipe.cycle(count=(18*len(envs))+3) 
pipe = GymStepper(pipe,seed=0,synchronized_reset=True)

# %%
steps = list(pipe)
gsteps = groupby(steps,lambda o:int(o.step_n))
test_len(gsteps.keys(),18)
pd.DataFrame([step for step in steps])[['state','terminated','env_id','episode_n','step_n']][::10]
# Out:
#                                                                    state  \
# 0    [tensor(0.0137), tensor(-0.0230), tensor(-0.0459), tensor(-0.0483)]
# 10    [tensor(0.0241), tensor(0.5643), tensor(-0.0672), tensor(-0.9714)]
# 20   [tensor(0.0463), tensor(-0.0172), tensor(-0.1094), tensor(-0.1771)]
# 30    [tensor(0.0217), tensor(-0.4009), tensor(-0.0929), tensor(0.2661)]
# 40    [tensor(0.0094), tensor(0.1879), tensor(-0.0961), tensor(-0.6926)]
# 50    [tensor(0.0325), tensor(0.7771), tensor(-0.1570), tensor(-1.6694)]
# 60    [tensor(0.0167), tensor(0.3685), tensor(-0.0540), tensor(-0.6622)]
# 70    [tensor(0.0427), tensor(0.1763), tensor(-0.1007), tensor(-0.4364)]
# 80    [tensor(0.0417), tensor(-0.4040), tensor(-0.1113), tensor(0.3342)]
# 90   [tensor(0.0096), tensor(-0.0083), tensor(-0.0886), tensor(-0.3733)]
# 100   [tensor(0.0209), tensor(0.5806), tensor(-0.1302), tensor(-1.3390)]
# 110  [tensor(0.0137), tensor(-0.0230), tensor(-0.0459), tensor(-0.0483)]
# 120   [tensor(0.0353), tensor(0.3702), tensor(-0.0866), tensor(-0.7006)]
# 130   [tensor(0.0459), tensor(-0.2106), tensor(-0.1129), tensor(0.0792)]
# 140   [tensor(0.0217), tensor(-0.4009), tensor(-0.0929), tensor(0.2661)]
# 150   [tensor(0.0132), tensor(0.3842), tensor(-0.1099), tensor(-1.0139)]
# 160   [tensor(0.0480), tensor(0.9737), tensor(-0.1904), tensor(-2.0066)]
#
#         terminated                   env_id  episode_n      step_n
# 0    tensor(False)  tensor(140042429428368)  tensor(1)   tensor(1)
# 10   tensor(False)  tensor(140042429429328)  tensor(1)   tensor(4)
# 20   tensor(False)  tensor(140042429429968)  tensor(1)   tensor(7)
# 30   tensor(False)  tensor(140042429428368)  tensor(1)  tensor(11)
# 40   tensor(False)  tensor(140042429429328)  tensor(1)  tensor(14)
# 50   tensor(False)  tensor(140042429429968)  tensor(1)  tensor(17)
# 60   tensor(False)  tensor(140042429428368)  tensor(2)   tensor(3)
# 70   tensor(False)  tensor(140042429429328)  tensor(2)   tensor(6)
# 80   tensor(False)  tensor(140042429429968)  tensor(2)   tensor(9)
# 90   tensor(False)  tensor(140042429428368)  tensor(2)  tensor(13)
# 100  tensor(False)  tensor(140042429429328)  tensor(2)  tensor(16)
# 110  tensor(False)  tensor(140042429429968)  tensor(3)   tensor(1)
# 120  tensor(False)  tensor(140042429428368)  tensor(3)   tensor(5)
# 130  tensor(False)  tensor(140042429429328)  tensor(3)   tensor(8)
# 140  tensor(False)  tensor(140042429429968)  tensor(3)  tensor(11)
# 150  tensor(False)  tensor(140042429428368)  tensor(3)  tensor(15)
# 160   tensor(True)  tensor(140042429429328)  tensor(3)  tensor(18)

# %% [markdown]
# All of the step groups should be the same length...

# %%
group_sz = None
for name,group in gsteps.items():
    if group_sz is None: group_sz = len(group)
    else:                assert len(group)==group_sz,f' Got lengths {len(group)} and {group_sz} for {name}.\n\n{group}'

# %% [markdown]
# Each step group's state and next_states should match across envs...

# %%
group_sz = None
for name,group in gsteps.items():
    e1 = group[0]
    for other in group[1:]: test_eq(e1.state,other.state)
    for other in group[1:]: test_eq(e1.next_state,other.next_state)

# %% [markdown]
# Each step group value should not show up/be duplicated in any other step groups...

# %%
group_sz = None
for name,group in gsteps.items():
    e1 = group[0]
    for other_name,other_group in gsteps.items():
        if other_name==name: continue
        for other in other_group[1:]: test_ne(e1.state,other.state)
        for other in other_group[1:]: test_ne(e1.next_state,other.next_state)

# %% [markdown]
# Given 3 envs, single steps, epsiodes of 18 steps in len, 3 episodes each, run for 162 iterations, we should
# expect there to be 9 dones.

# %%
test_eq(sum([o.terminated for o in steps]),tensor([9]))

# %% [markdown]
# The max episode numbers for each env should sum to 9 where for each env, it should reach and finish 3 episodes...

# %%
gsteps = groupby(steps,lambda o:int(o.env_id))
test_len(gsteps.keys(),3)
env1,env2,env3 = L(gsteps.values()).map(L).map(Self.map(Self.episode_n()).map(int))
test_eq(max(env1)+max(env2)+max(env3),9)

# %%
import pandas as pd

envs = ['CartPole-v1']*10

pipe = dp.map.Mapper(envs)
pipe = TypeTransformLoop(pipe,[GymTypeTransform])
pipe = dp.iter.MapToIterConverter(pipe)
pipe = dp.iter.InMemoryCacheHolder(pipe)
pipe = pipe.cycle(count=(18*len(envs))) 
# Turn off the seed so that some envs end before others...
pipe = GymStepper(pipe,synchronized_reset=True)
steps = list(pipe)

# %% [markdown]
# Since the seed is turned off the only properties we are to expect are:
#
#     - If an env finishes, no steps from that env should be seen until all 9 of the other envs finish

# %%
def synchronized_reset_checker(steps):
    env_id_done_tracker = {}
    did_syncs_happen = False
    for d,env_id,idx in [(bool(o.terminated),int(o.env_id),i) for i,o in enumerate(steps)]:

        if d: 
            env_id_done_tracker[env_id] = idx
            continue

        if env_id in env_id_done_tracker:
            if len(env_id_done_tracker)!=len(envs):
                raise Exception(f'env_id {env_id} was iterated through when it should not have been! idx: {idx}')
        if len(env_id_done_tracker)==len(envs):
            did_syncs_happen = True
            env_id_done_tracker = {}

    if not did_syncs_happen: 
        raise Exception('There should have at least been 1 time where all the envs had to reset, which did not happen.')
synchronized_reset_checker(steps)

# %% [markdown]
# For sanity, we should expect that without `synchronized_reset` envs will be reset and stepped through before other
# envs are reset, `synchronized_reset_checker` should fail.

# %%
pipe = dp.map.Mapper(envs)
pipe = TypeTransformLoop(pipe,[GymTypeTransform])
pipe = dp.iter.MapToIterConverter(pipe)
pipe = dp.iter.InMemoryCacheHolder(pipe)
pipe = pipe.cycle(count=(18*len(envs))) 
# Turn off the seed so that some envs end before others...
pipe = GymStepper(pipe)
steps = list(pipe)

# %%
with ExceptionExpected(regex='was iterated through when it should not have been'):
    synchronized_reset_checker(steps)

# %%
#|export
def isrecord(o): return type(o)==Record
def isnone(o): return o is None
def GymTransformBlock(
    agent,
    seed=None,
    nsteps=1,
    nskips=1,
    firstlast=False,
    dl_type=DataLoader2,
    pipe_fn_kwargs=None,
    type_tfms=None,
    **kwargs
):
    pipe_fn_kwargs = ifnone(pipe_fn_kwargs,{})
    type_tfms = ifnone(type_tfms,GymTypeTransform)
    
    def pipe_fn(source:List[str],bs,n,seed,nsteps,nskips,synchronized_reset=False, 
                firstlast=False,
                include_images=False,type_tfms=None,item_tfms=None,batch_tfms=None,cbs=None):
        pipe = dp.map.Mapper(source)
        pipe = TypeTransformLoop(pipe,type_tfms)
        pipe = dp.iter.MapToIterConverter(pipe)
        pipe = dp.iter.InMemoryCacheHolder(pipe)
        pipe = pipe.cycle() # Cycle through the envs inf
        pipe = GymStepper(pipe,agent=agent,seed=seed,
                          include_images=include_images,synchronized_reset=synchronized_reset)
        if nskips!=1: pipe = NSkipper(pipe,n=nskips)
        if nsteps!=1:
            pipe = NStepper(pipe,n=nsteps)
            if firstlast:
                pipe = FirstLastMerger(pipe)
            else:
                pipe = dp.iter.Flattener(pipe) # We dont want to flatten if using FirstLastMerger
        if n is not None: pipe = pipe.header(limit=n)
        pipe = ItemTransformLoop(pipe,item_tfms)
        pipe  = pipe.batch(batch_size=bs)
        pipe = BatchTransformLoop(pipe,batch_tfms)
        return pipe

    return TransformBlock(
        pipe_fn = pipe_fn,
        dl_type = dl_type,
        pipe_fn_kwargs = merge(pipe_fn_kwargs,kwargs,dict(nsteps=nsteps,nskips=nskips,seed=seed,firstlast=firstlast,
                                                          type_tfms=type_tfms))
    )

# %%
import pandas as pd
pd.set_option('display.max_rows', 50)

envs = ['CartPole-v1']*3
block = GymTransformBlock(None,nsteps=2,nskips=2,firstlast=True)
pipes = block.pipe_fn(envs,bs=1,n=100,**block.pipe_fn_kwargs)
pd.DataFrame([o[0] for o in pipes])[['state','action','terminated','reward']][:50]
# Out:
#                                                                    state  \
# 0      [tensor(0.0093), tensor(0.0174), tensor(-0.0336), tensor(0.0367)]
# 1    [tensor(-0.0018), tensor(-0.0089), tensor(0.0444), tensor(-0.0143)]
# 2      [tensor(-0.0170), tensor(0.0459), tensor(0.0215), tensor(0.0241)]
# 3     [tensor(0.0096), tensor(-0.1773), tensor(-0.0328), tensor(0.3186)]
# 4     [tensor(-0.0019), tensor(-0.2046), tensor(0.0441), tensor(0.2921)]
# 5     [tensor(-0.0161), tensor(-0.1495), tensor(0.0220), tensor(0.3235)]
# 6    [tensor(-0.0014), tensor(-0.1764), tensor(-0.0144), tensor(0.2999)]
# 7     [tensor(-0.0062), tensor(0.1842), tensor(0.0502), tensor(-0.2629)]
# 8     [tensor(-0.0260), tensor(-0.1502), tensor(0.0409), tensor(0.3394)]
# 9    [tensor(-0.0045), tensor(-0.1761), tensor(-0.0084), tensor(0.2927)]
# 10     [tensor(0.0050), tensor(0.1829), tensor(0.0342), tensor(-0.2328)]
# 11    [tensor(-0.0359), tensor(-0.5417), tensor(0.0606), tensor(0.9521)]
# 12   [tensor(-0.0077), tensor(0.2143), tensor(-0.0026), tensor(-0.2961)]
# 13     [tensor(0.0084), tensor(0.1820), tensor(0.0310), tensor(-0.2127)]
# 14    [tensor(-0.0615), tensor(-0.5435), tensor(0.1049), tensor(0.9964)]
# 15    [tensor(0.0048), tensor(0.6047), tensor(-0.0203), tensor(-0.8849)]
# 16     [tensor(0.0196), tensor(0.5714), tensor(0.0168), tensor(-0.7796)]
# 17    [tensor(-0.0872), tensor(-0.5466), tensor(0.1512), tensor(1.0690)]
# 18    [tensor(0.0251), tensor(0.2153), tensor(-0.0500), tensor(-0.3182)]
# 19    [tensor(0.0385), tensor(0.5711), tensor(-0.0084), tensor(-0.7740)]
# 20    [tensor(-0.1052), tensor(-0.1613), tensor(0.1892), tensor(0.5935)]
# 21     [tensor(-0.1078), tensor(0.2225), tensor(0.2084), tensor(0.1427)]
# 22    [tensor(0.0298), tensor(-0.1733), tensor(-0.0572), tensor(0.2327)]
# 23    [tensor(0.0575), tensor(0.5716), tensor(-0.0336), tensor(-0.7841)]
# 24   [tensor(-0.0127), tensor(-0.0116), tensor(0.0420), tensor(-0.0066)]
# 25    [tensor(0.0190), tensor(-0.5620), tensor(-0.0424), tensor(0.7825)]
# 26    [tensor(0.0843), tensor(0.5727), tensor(-0.0710), tensor(-0.8104)]
# 27    [tensor(-0.0093), tensor(-0.0128), tensor(0.0361), tensor(0.0198)]
# 28   [tensor(-0.0074), tensor(-0.5610), tensor(-0.0055), tensor(0.7606)]
# 29    [tensor(0.1111), tensor(0.9649), tensor(-0.1097), tensor(-1.4432)]
# 30    [tensor(0.1536), tensor(0.9679), tensor(-0.1739), tensor(-1.5215)]
# 31    [tensor(0.1730), tensor(0.7752), tensor(-0.2044), tensor(-1.2878)]
# 32    [tensor(-0.0137), tensor(-0.4040), tensor(0.0430), tensor(0.6277)]
# 33    [tensor(-0.0337), tensor(-0.5611), tensor(0.0307), tensor(0.7619)]
# 34    [tensor(-0.0338), tensor(-0.7956), tensor(0.0742), tensor(1.2432)]
# 35    [tensor(-0.0601), tensor(-0.9523), tensor(0.0673), tensor(1.3709)]
# 36  [tensor(-0.0231), tensor(-0.0275), tensor(-0.0376), tensor(-0.0264)]
# 37    [tensor(-0.0617), tensor(-0.7978), tensor(0.1186), tensor(1.2967)]
# 38    [tensor(-0.0975), tensor(-1.1907), tensor(0.1770), tensor(1.9581)]
# 39    [tensor(-0.0943), tensor(-0.5643), tensor(0.1167), tensor(0.8384)]
# 40   [tensor(-0.0281), tensor(-0.4166), tensor(-0.0331), tensor(0.5346)]
# 41    [tensor(-0.1208), tensor(-0.9574), tensor(0.1568), tensor(1.4968)]
# 42    [tensor(-0.1399), tensor(-1.1540), tensor(0.1867), tensor(1.8340)]
# 43   [tensor(-0.0487), tensor(-0.8061), tensor(-0.0061), tensor(1.1022)]
# 44    [tensor(-0.0241), tensor(0.0063), tensor(-0.0321), tensor(0.0305)]
# 45   [tensor(0.0036), tensor(-0.0043), tensor(-0.0458), tensor(-0.0192)]
# 46    [tensor(-0.0770), tensor(-0.4160), tensor(0.0321), tensor(0.5200)]
# 47    [tensor(-0.0277), tensor(0.0073), tensor(-0.0252), tensor(0.0105)]
# 48    [tensor(0.0073), tensor(0.3872), tensor(-0.0527), tensor(-0.6329)]
# 49   [tensor(-0.0897), tensor(-0.0268), tensor(0.0473), tensor(-0.0413)]
#
#         action     terminated          reward
# 0   tensor(0.)  tensor(False)  tensor(1.9900)
# 1   tensor(0.)  tensor(False)  tensor(1.9900)
# 2   tensor(0.)  tensor(False)  tensor(1.9900)
# 3   tensor(0.)  tensor(False)  tensor(1.9900)
# 4   tensor(1.)  tensor(False)  tensor(1.9900)
# 5   tensor(0.)  tensor(False)  tensor(1.9900)
# 6   tensor(1.)  tensor(False)  tensor(1.9900)
# 7   tensor(1.)  tensor(False)  tensor(1.9900)
# 8   tensor(0.)  tensor(False)  tensor(1.9900)
# 9   tensor(1.)  tensor(False)  tensor(1.9900)
# 10  tensor(0.)  tensor(False)  tensor(1.9900)
# 11  tensor(0.)  tensor(False)  tensor(1.9900)
# 12  tensor(1.)  tensor(False)  tensor(1.9900)
# 13  tensor(1.)  tensor(False)  tensor(1.9900)
# 14  tensor(0.)  tensor(False)  tensor(1.9900)
# 15  tensor(0.)  tensor(False)  tensor(1.9900)
# 16  tensor(0.)  tensor(False)  tensor(1.9900)
# 17  tensor(1.)  tensor(False)  tensor(1.9900)
# 18  tensor(0.)  tensor(False)  tensor(1.9900)
# 19  tensor(0.)  tensor(False)  tensor(1.9900)
# 20  tensor(1.)   tensor(True)  tensor(1.9900)
# 21  tensor(0.)   tensor(True)      tensor(1.)
# 22  tensor(0.)  tensor(False)  tensor(1.9900)
# 23  tensor(1.)  tensor(False)  tensor(1.9900)
# 24  tensor(1.)  tensor(False)  tensor(1.9900)
# 25  tensor(0.)  tensor(False)  tensor(1.9900)
# 26  tensor(1.)  tensor(False)  tensor(1.9900)
# 27  tensor(0.)  tensor(False)  tensor(1.9900)
# 28  tensor(0.)  tensor(False)  tensor(1.9900)
# 29  tensor(1.)  tensor(False)  tensor(1.9900)
# 30  tensor(0.)   tensor(True)  tensor(1.9900)
# 31  tensor(1.)   tensor(True)      tensor(1.)
# 32  tensor(0.)  tensor(False)  tensor(1.9900)
# 33  tensor(0.)  tensor(False)  tensor(1.9900)
# 34  tensor(1.)  tensor(False)  tensor(1.9900)
# 35  tensor(1.)  tensor(False)  tensor(1.9900)
# 36  tensor(0.)  tensor(False)  tensor(1.9900)
# 37  tensor(0.)   tensor(True)  tensor(1.9900)
# 38  tensor(1.)   tensor(True)      tensor(1.)
# 39  tensor(0.)  tensor(False)  tensor(1.9900)
# 40  tensor(0.)  tensor(False)  tensor(1.9900)
# 41  tensor(0.)   tensor(True)  tensor(1.9900)
# 42  tensor(1.)   tensor(True)      tensor(1.)
# 43  tensor(1.)  tensor(False)  tensor(1.9900)
# 44  tensor(0.)  tensor(False)  tensor(1.9900)
# 45  tensor(1.)  tensor(False)  tensor(1.9900)
# 46  tensor(1.)  tensor(False)  tensor(1.9900)
# 47  tensor(1.)  tensor(False)  tensor(1.9900)
# 48  tensor(1.)  tensor(False)  tensor(1.9900)
# 49  tensor(0.)  tensor(False)  tensor(1.9900)

# %%
import pandas as pd
pd.set_option('display.max_rows', 50)

envs = ['CartPole-v1']*3
block = GymTransformBlock(None,nsteps=1,nskips=1,firstlast=False)
pipes = block.pipe_fn(envs,bs=1,n=100,**block.pipe_fn_kwargs)
pd.DataFrame([o[0] for o in pipes])[['state','action','terminated','reward']][:50]
# Out:
#                                                                  state  \
# 0    [tensor(0.0214), tensor(0.0025), tensor(0.0413), tensor(-0.0096)]
# 1    [tensor(0.0069), tensor(0.0111), tensor(0.0424), tensor(-0.0214)]
# 2   [tensor(0.0470), tensor(0.0023), tensor(-0.0233), tensor(-0.0217)]
# 3    [tensor(0.0214), tensor(-0.1931), tensor(0.0411), tensor(0.2958)]
# 4    [tensor(0.0071), tensor(-0.1846), tensor(0.0420), tensor(0.2844)]
# 5   [tensor(0.0470), tensor(0.1977), tensor(-0.0238), tensor(-0.3217)]
# 6     [tensor(0.0176), tensor(0.0014), tensor(0.0470), tensor(0.0163)]
# 7     [tensor(0.0034), tensor(0.0099), tensor(0.0477), tensor(0.0052)]
# 8   [tensor(0.0510), tensor(0.0030), tensor(-0.0302), tensor(-0.0366)]
# 9    [tensor(0.0176), tensor(-0.1944), tensor(0.0473), tensor(0.3235)]
# 10   [tensor(0.0036), tensor(0.2043), tensor(0.0478), tensor(-0.2720)]
# 11  [tensor(0.0511), tensor(0.1985), tensor(-0.0309), tensor(-0.3386)]
# 12   [tensor(0.0137), tensor(-0.3902), tensor(0.0538), tensor(0.6307)]
# 13   [tensor(0.0077), tensor(0.3987), tensor(0.0423), tensor(-0.5493)]
# 14  [tensor(0.0550), tensor(0.0038), tensor(-0.0377), tensor(-0.0559)]
# 15   [tensor(0.0059), tensor(-0.1958), tensor(0.0664), tensor(0.3554)]
# 16   [tensor(0.0157), tensor(0.5932), tensor(0.0313), tensor(-0.8283)]
# 17  [tensor(0.0551), tensor(-0.1907), tensor(-0.0388), tensor(0.2247)]
# 18   [tensor(0.0020), tensor(-0.0017), tensor(0.0735), tensor(0.0844)]
# 19   [tensor(0.0275), tensor(0.3977), tensor(0.0148), tensor(-0.5260)]
# 20  [tensor(0.0513), tensor(0.0049), tensor(-0.0343), tensor(-0.0800)]
# 21   [tensor(0.0019), tensor(-0.1978), tensor(0.0752), tensor(0.3993)]
# 22   [tensor(0.0355), tensor(0.5926), tensor(0.0043), tensor(-0.8139)]
# 23  [tensor(0.0514), tensor(0.2005), tensor(-0.0359), tensor(-0.3833)]
# 24  [tensor(-0.0020), tensor(-0.3939), tensor(0.0832), tensor(0.7148)]
# 25  [tensor(0.0473), tensor(0.3974), tensor(-0.0120), tensor(-0.5199)]
# 26  [tensor(0.0554), tensor(0.0059), tensor(-0.0436), tensor(-0.1022)]
# 27  [tensor(-0.0099), tensor(-0.5901), tensor(0.0975), tensor(1.0324)]
# 28  [tensor(0.0553), tensor(0.2025), tensor(-0.0224), tensor(-0.2311)]
# 29  [tensor(0.0555), tensor(0.2016), tensor(-0.0456), tensor(-0.4083)]
# 30  [tensor(-0.0217), tensor(-0.3964), tensor(0.1181), tensor(0.7719)]
# 31   [tensor(0.0593), tensor(0.0077), tensor(-0.0270), tensor(0.0545)]
# 32  [tensor(0.0595), tensor(0.0072), tensor(-0.0538), tensor(-0.1303)]
# 33  [tensor(-0.0296), tensor(-0.5929), tensor(0.1336), tensor(1.0993)]
# 34  [tensor(0.0595), tensor(-0.1871), tensor(-0.0259), tensor(0.3385)]
# 35  [tensor(0.0597), tensor(-0.1871), tensor(-0.0564), tensor(0.1449)]
# 36  [tensor(-0.0415), tensor(-0.3998), tensor(0.1555), tensor(0.8513)]
# 37   [tensor(0.0557), tensor(0.0084), tensor(-0.0192), tensor(0.0378)]
# 38  [tensor(0.0559), tensor(-0.3814), tensor(-0.0535), tensor(0.4192)]
# 39  [tensor(-0.0495), tensor(-0.2071), tensor(0.1726), tensor(0.6113)]
# 40  [tensor(0.0559), tensor(0.2038), tensor(-0.0184), tensor(-0.2609)]
# 41  [tensor(0.0483), tensor(-0.5757), tensor(-0.0451), tensor(0.6946)]
# 42  [tensor(-0.0536), tensor(-0.0147), tensor(0.1848), tensor(0.3775)]
# 43   [tensor(0.0600), tensor(0.0090), tensor(-0.0236), tensor(0.0259)]
# 44  [tensor(0.0368), tensor(-0.7702), tensor(-0.0312), tensor(0.9727)]
# 45   [tensor(-0.0539), tensor(0.1773), tensor(0.1924), tensor(0.1483)]
# 46  [tensor(0.0602), tensor(-0.1858), tensor(-0.0231), tensor(0.3110)]
# 47  [tensor(0.0214), tensor(-0.5746), tensor(-0.0118), tensor(0.6704)]
# 48  [tensor(-0.0504), tensor(-0.0199), tensor(0.1953), tensor(0.4950)]
# 49   [tensor(0.0564), tensor(0.0096), tensor(-0.0169), tensor(0.0112)]
#
#         action     terminated      reward
# 0   tensor(0.)  tensor(False)  tensor(1.)
# 1   tensor(0.)  tensor(False)  tensor(1.)
# 2   tensor(1.)  tensor(False)  tensor(1.)
# 3   tensor(1.)  tensor(False)  tensor(1.)
# 4   tensor(1.)  tensor(False)  tensor(1.)
# 5   tensor(0.)  tensor(False)  tensor(1.)
# 6   tensor(0.)  tensor(False)  tensor(1.)
# 7   tensor(1.)  tensor(False)  tensor(1.)
# 8   tensor(1.)  tensor(False)  tensor(1.)
# 9   tensor(0.)  tensor(False)  tensor(1.)
# 10  tensor(1.)  tensor(False)  tensor(1.)
# 11  tensor(0.)  tensor(False)  tensor(1.)
# 12  tensor(1.)  tensor(False)  tensor(1.)
# 13  tensor(1.)  tensor(False)  tensor(1.)
# 14  tensor(0.)  tensor(False)  tensor(1.)
# 15  tensor(1.)  tensor(False)  tensor(1.)
# 16  tensor(0.)  tensor(False)  tensor(1.)
# 17  tensor(1.)  tensor(False)  tensor(1.)
# 18  tensor(0.)  tensor(False)  tensor(1.)
# 19  tensor(1.)  tensor(False)  tensor(1.)
# 20  tensor(1.)  tensor(False)  tensor(1.)
# 21  tensor(0.)  tensor(False)  tensor(1.)
# 22  tensor(0.)  tensor(False)  tensor(1.)
# 23  tensor(0.)  tensor(False)  tensor(1.)
# 24  tensor(0.)  tensor(False)  tensor(1.)
# 25  tensor(0.)  tensor(False)  tensor(1.)
# 26  tensor(1.)  tensor(False)  tensor(1.)
# 27  tensor(1.)  tensor(False)  tensor(1.)
# 28  tensor(0.)  tensor(False)  tensor(1.)
# 29  tensor(0.)  tensor(False)  tensor(1.)
# 30  tensor(0.)  tensor(False)  tensor(1.)
# 31  tensor(0.)  tensor(False)  tensor(1.)
# 32  tensor(0.)  tensor(False)  tensor(1.)
# 33  tensor(1.)  tensor(False)  tensor(1.)
# 34  tensor(1.)  tensor(False)  tensor(1.)
# 35  tensor(0.)  tensor(False)  tensor(1.)
# 36  tensor(1.)  tensor(False)  tensor(1.)
# 37  tensor(1.)  tensor(False)  tensor(1.)
# 38  tensor(0.)  tensor(False)  tensor(1.)
# 39  tensor(1.)  tensor(False)  tensor(1.)
# 40  tensor(0.)  tensor(False)  tensor(1.)
# 41  tensor(0.)  tensor(False)  tensor(1.)
# 42  tensor(1.)  tensor(False)  tensor(1.)
# 43  tensor(0.)  tensor(False)  tensor(1.)
# 44  tensor(1.)  tensor(False)  tensor(1.)
# 45  tensor(0.)  tensor(False)  tensor(1.)
# 46  tensor(1.)  tensor(False)  tensor(1.)
# 47  tensor(1.)  tensor(False)  tensor(1.)
# 48  tensor(1.)  tensor(False)  tensor(1.)
# 49  tensor(0.)  tensor(False)  tensor(1.)

# %%
import pandas as pd
pd.set_option('display.max_rows', 50)

envs = ['CartPole-v1']*3
block = GymTransformBlock(None,nsteps=2,nskips=1,firstlast=True)
pipes = block.pipe_fn(envs,bs=1,n=100,**block.pipe_fn_kwargs)
pd.DataFrame([o[0] for o in pipes])[['state','action','terminated','reward']][:50]
# Out:
#                                                                      state  \
# 0         [tensor(0.0169), tensor(0.0467), tensor(0.0272), tensor(0.0416)]
# 1       [tensor(0.0132), tensor(-0.0498), tensor(-0.0063), tensor(0.0392)]
# 2       [tensor(0.0020), tensor(-0.0134), tensor(-0.0173), tensor(0.0151)]
# 3        [tensor(0.0179), tensor(-0.1488), tensor(0.0281), tensor(0.3427)]
# 4       [tensor(0.0122), tensor(-0.2448), tensor(-0.0055), tensor(0.3299)]
# 5       [tensor(0.0017), tensor(0.1820), tensor(-0.0170), tensor(-0.2830)]
# 6        [tensor(0.0149), tensor(-0.3443), tensor(0.0349), tensor(0.6441)]
# 7        [tensor(0.0073), tensor(-0.0496), tensor(0.0011), tensor(0.0355)]
# 8       [tensor(0.0054), tensor(-0.0129), tensor(-0.0227), tensor(0.0043)]
# 9        [tensor(0.0080), tensor(-0.5399), tensor(0.0478), tensor(0.9476)]
# 10       [tensor(0.0063), tensor(-0.2448), tensor(0.0018), tensor(0.3285)]
# 11      [tensor(0.0051), tensor(-0.2077), tensor(-0.0226), tensor(0.2897)]
# 12      [tensor(-0.0028), tensor(-0.3455), tensor(0.0667), tensor(0.6703)]
# 13       [tensor(0.0014), tensor(-0.0497), tensor(0.0084), tensor(0.0364)]
# 14     [tensor(0.0010), tensor(-0.0123), tensor(-0.0168), tensor(-0.0100)]
# 15      [tensor(-0.0097), tensor(-0.5415), tensor(0.0802), tensor(0.9832)]
# 16       [tensor(0.0004), tensor(-0.2449), tensor(0.0091), tensor(0.3317)]
# 17      [tensor(0.0007), tensor(-0.2072), tensor(-0.0170), tensor(0.2773)]
# 18      [tensor(-0.0205), tensor(-0.3475), tensor(0.0998), tensor(0.7168)]
# 19      [tensor(-0.0045), tensor(-0.0499), tensor(0.0157), tensor(0.0419)]
# 20    [tensor(-0.0034), tensor(-0.0118), tensor(-0.0115), tensor(-0.0207)]
# 21      [tensor(-0.0275), tensor(-0.5438), tensor(0.1142), tensor(1.0391)]
# 22      [tensor(-0.0055), tensor(0.1450), tensor(0.0166), tensor(-0.2458)]
# 23     [tensor(-0.0037), tensor(0.1835), tensor(-0.0119), tensor(-0.3170)]
# 24      [tensor(-0.0384), tensor(-0.3504), tensor(0.1349), tensor(0.7844)]
# 25      [tensor(-0.0026), tensor(-0.0504), tensor(0.0116), tensor(0.0520)]
# 26  [tensor(3.1726e-06), tensor(0.3788), tensor(-0.0182), tensor(-0.6134)]
# 27      [tensor(-0.0454), tensor(-0.1574), tensor(0.1506), tensor(0.5370)]
# 28      [tensor(-0.0036), tensor(-0.2457), tensor(0.0127), tensor(0.3484)]
# 29      [tensor(0.0076), tensor(0.5742), tensor(-0.0305), tensor(-0.9117)]
# 30      [tensor(-0.0485), tensor(-0.3543), tensor(0.1614), tensor(0.8731)]
# 31      [tensor(-0.0085), tensor(-0.0507), tensor(0.0196), tensor(0.0597)]
# 32      [tensor(0.0191), tensor(0.7697), tensor(-0.0487), tensor(-1.2138)]
# 33      [tensor(-0.0556), tensor(-0.5512), tensor(0.1788), tensor(1.2118)]
# 34      [tensor(-0.0666), tensor(-0.7481), tensor(0.2031), tensor(1.5548)]
# 35      [tensor(-0.0095), tensor(0.1441), tensor(0.0208), tensor(-0.2267)]
# 36      [tensor(0.0345), tensor(0.9654), tensor(-0.0730), tensor(-1.5214)]
# 37      [tensor(-0.0066), tensor(0.3389), tensor(0.0163), tensor(-0.5128)]
# 38      [tensor(0.0538), tensor(1.1613), tensor(-0.1034), tensor(-1.8359)]
# 39      [tensor(-0.0388), tensor(0.0483), tensor(-0.0402), tensor(0.0462)]
# 40       [tensor(0.0001), tensor(0.1436), tensor(0.0060), tensor(-0.2150)]
# 41      [tensor(0.0770), tensor(1.3574), tensor(-0.1401), tensor(-2.1589)]
# 42      [tensor(0.1041), tensor(1.1639), tensor(-0.1833), tensor(-1.9125)]
# 43     [tensor(-0.0378), tensor(-0.1462), tensor(-0.0393), tensor(0.3260)]
# 44       [tensor(0.0030), tensor(-0.0516), tensor(0.0017), tensor(0.0796)]
# 45     [tensor(-0.0407), tensor(-0.3408), tensor(-0.0328), tensor(0.6060)]
# 46       [tensor(0.0020), tensor(0.1435), tensor(0.0033), tensor(-0.2125)]
# 47       [tensor(0.0092), tensor(-0.0438), tensor(0.0326), tensor(0.0191)]
# 48     [tensor(-0.0476), tensor(-0.5354), tensor(-0.0207), tensor(0.8882)]
# 49      [tensor(0.0048), tensor(0.3385), tensor(-0.0009), tensor(-0.5042)]
#
#         action     terminated          reward
# 0   tensor(0.)  tensor(False)  tensor(1.9900)
# 1   tensor(0.)  tensor(False)  tensor(1.9900)
# 2   tensor(1.)  tensor(False)  tensor(1.9900)
# 3   tensor(0.)  tensor(False)  tensor(1.9900)
# 4   tensor(1.)  tensor(False)  tensor(1.9900)
# 5   tensor(0.)  tensor(False)  tensor(1.9900)
# 6   tensor(0.)  tensor(False)  tensor(1.9900)
# 7   tensor(0.)  tensor(False)  tensor(1.9900)
# 8   tensor(0.)  tensor(False)  tensor(1.9900)
# 9   tensor(1.)  tensor(False)  tensor(1.9900)
# 10  tensor(1.)  tensor(False)  tensor(1.9900)
# 11  tensor(1.)  tensor(False)  tensor(1.9900)
# 12  tensor(0.)  tensor(False)  tensor(1.9900)
# 13  tensor(0.)  tensor(False)  tensor(1.9900)
# 14  tensor(0.)  tensor(False)  tensor(1.9900)
# 15  tensor(1.)  tensor(False)  tensor(1.9900)
# 16  tensor(1.)  tensor(False)  tensor(1.9900)
# 17  tensor(1.)  tensor(False)  tensor(1.9900)
# 18  tensor(0.)  tensor(False)  tensor(1.9900)
# 19  tensor(1.)  tensor(False)  tensor(1.9900)
# 20  tensor(1.)  tensor(False)  tensor(1.9900)
# 21  tensor(1.)  tensor(False)  tensor(1.9900)
# 22  tensor(0.)  tensor(False)  tensor(1.9900)
# 23  tensor(1.)  tensor(False)  tensor(1.9900)
# 24  tensor(1.)  tensor(False)  tensor(1.9900)
# 25  tensor(0.)  tensor(False)  tensor(1.9900)
# 26  tensor(1.)  tensor(False)  tensor(1.9900)
# 27  tensor(0.)  tensor(False)  tensor(1.9900)
# 28  tensor(1.)  tensor(False)  tensor(1.9900)
# 29  tensor(1.)  tensor(False)  tensor(1.9900)
# 30  tensor(0.)  tensor(False)  tensor(1.9900)
# 31  tensor(1.)  tensor(False)  tensor(1.9900)
# 32  tensor(1.)  tensor(False)  tensor(1.9900)
# 33  tensor(0.)   tensor(True)  tensor(1.9900)
# 34  tensor(0.)   tensor(True)      tensor(1.)
# 35  tensor(1.)  tensor(False)  tensor(1.9900)
# 36  tensor(1.)  tensor(False)  tensor(1.9900)
# 37  tensor(0.)  tensor(False)  tensor(1.9900)
# 38  tensor(1.)  tensor(False)  tensor(1.9900)
# 39  tensor(0.)  tensor(False)  tensor(1.9900)
# 40  tensor(0.)  tensor(False)  tensor(1.9900)
# 41  tensor(0.)   tensor(True)  tensor(1.9900)
# 42  tensor(0.)   tensor(True)      tensor(1.)
# 43  tensor(0.)  tensor(False)  tensor(1.9900)
# 44  tensor(1.)  tensor(False)  tensor(1.9900)
# 45  tensor(0.)  tensor(False)  tensor(1.9900)
# 46  tensor(1.)  tensor(False)  tensor(1.9900)
# 47  tensor(1.)  tensor(False)  tensor(1.9900)
# 48  tensor(0.)  tensor(False)  tensor(1.9900)
# 49  tensor(1.)  tensor(False)  tensor(1.9900)

# %% [markdown]
# ## Multi Processing

# %%
# %%writefile external_run_scripts/spawn_multiproc.py
import torch
import torchdata.datapipes as dp
from torch.utils.data.dataloader_experimental import DataLoader2
       
class PointlessLoop(dp.iter.IterDataPipe):
    def __init__(self,datapipe=None):
        self.datapipe = datapipe
    
    def __iter__(self):
        while True:
            yield torch.LongTensor(4).detach().clone()
            

if __name__=='__main__':
    from torch.multiprocessing import Pool, Process, set_start_method
    try:
         set_start_method('spawn')
    except RuntimeError:
        pass


    pipe = PointlessLoop()
    pipe = pipe.header(limit=10)
    dls = [DataLoader2(pipe,num_workers=1)]
    # Setup the Learner
    print('type: ',type(dls[0]))
    for o in dls[0]:
        print(o)
# Out:
# Overwriting external_run_scripts/spawn_multiproc.py

# %%
# %%python external_run_scripts/spawn_multiproc.py
# print('hi')
# Out:
# type:  <class 'torch.utils.data.dataloader.DataLoader'>
# tensor([[     140567866743024,      140567866435920, -9169020141401551106,
#               140567866743104]])
# tensor([[0, 0, 0, 0]])
# tensor([[7380385434626780513, 2314885530817018409, 8247626271654158368,
#          6858531898276388974]])
# tensor([[4692818020931172709, 7163384699806053493, 8247308551402910817,
#          7526769937393086057]])
# tensor([[2314861403006003572, 2821259013920923680, 2314885530818447911,
#          6858531898276388896]])
# tensor([[8101822292589296928, 2836549944597570928, 8388368157737231648,
#          6876843109089832803]])
# tensor([[7957695011165400435, 7526769937258802976, 8534075499220396832,
#          8032016439426708069]])
# tensor([[9018300393077547066, 2314885530818453514, 2334400003262391072,
#          7885648055777716340]])
# tensor([[1, 4, 0, 0]])
# tensor([[             0,              0, 94725616525952, 94725596143328]])

# %%
import pandas as pd
from tqdm.auto import tqdm
from fastrl.agents.dqn.basic import DQN,DQNAgent

from torch.utils.data.dataloader_experimental import DataLoader2
pd.set_option('display.max_rows', 50)

torch.manual_seed(0)
model = DQN(4,2)

agent = DQNAgent(model)

envs = ['CartPole-v1']*1
block = GymTransformBlock(agent,nsteps=1,nskips=1,firstlast=False #,batch_tfms=[lambda o: [step.clone().detach() for step in o]]
                         )
pipes = block.pipe_fn(envs,bs=1,n=1000,**block.pipe_fn_kwargs)

dl = DataLoader2(pipes,num_workers=1,batch_size=1,persistent_workers=True)

batches = []

for epoch in range(6):
    print('epoch ',epoch)
    for batch in tqdm(dl):
        # Without the "clone", this will fail.
        # batches.extend(batch)
        batches.extend([o.clone().detach() for o in batch])
# Out:
# epoch  0
# 0it [00:00, ?it/s]
# epoch  1
# 0it [00:00, ?it/s]
# epoch  2
# 0it [00:00, ?it/s]
# epoch  3
# 0it [00:00, ?it/s]
# epoch  4
# 0it [00:00, ?it/s]
# epoch  5
# 0it [00:00, ?it/s]

# %%
#|hide
from fastcore.imports import in_colab

# Since colab still requires tornado<6, we don't want to import nbdev if we don't have to
if not in_colab():
    from nbdev import nbdev_export
    nbdev_export()
